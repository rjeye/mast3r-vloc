# %%
import shutil
from tqdm import tqdm
from pathlib import Path
from natsort import natsorted

import cv2
import torch
import numpy as np
import matplotlib.pyplot as plt

# set plt to ioff
plt.ioff()

# for evo ######################################################################
from evo.tools import log
log.configure_logging(verbose=False, debug=False, silent=False)

import pprint
import numpy as np

from evo.tools import plot
import matplotlib.pyplot as plt

# temporarily override some package settings
from evo.tools.settings import SETTINGS
SETTINGS.plot_usetex = False

plot.apply_settings(SETTINGS)
# %matplotlib inline

from evo.tools import file_interface
from evo.core import metrics, sync
from evo.core.units import Unit
#############################################################################

# reload notebook automatically after changes to source python files
# %load_ext autoreload
# %autoreload 2

# change base folder to parent
import os
if os.path.basename(os.getcwd()) == 'notebooks':
    os.chdir('..')
print(os.getcwd())

# Set CUDA_VISIBLE_DEVICES
os.environ['CUDA_VISIBLE_DEVICES'] = '1'
# Out:
# /home/onyx/work_dirs/rjayanti/mast3r-vloc

# %%
from src.datasets.dataset_utils import read_intrinsics, load_tum_poses, PoseMode

dataset_root = Path("/home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/")
exps_root = Path("results/mast3rvloc-torwic/")

REF_DAY = "Jun15"
REF_RUN = "Aisle_CCW_Run_1"
QUERY_DAY = "Jun23"
QUERY_RUN = "Aisle_CW_Run_2"

# strip _ from Ref RUN and make Ref day and ref run lowercase and build the experiment name
experiment_name = f"{REF_DAY.lower()}-{REF_RUN.replace('_', '').lower()}-query-{QUERY_DAY.lower()}-{QUERY_RUN.replace('_', '').lower()}-asmk-retrieval"

exp_folder = exps_root / experiment_name
exp_folder.mkdir(parents=True, exist_ok=True)

ref_scene_folder = dataset_root / REF_DAY / REF_RUN
query_scene_folder = dataset_root / QUERY_DAY / QUERY_RUN

ref_poses_file = ref_scene_folder / "poses_camera_right_tum.txt"
ref_poses = load_tum_poses(ref_poses_file, PoseMode.TUM)
ref_rgb_folder = ref_scene_folder / "image_right"
ref_rgb_files = natsorted(list(ref_rgb_folder.glob("*.png")))
ref_depth_folder = ref_scene_folder / "depth_right"
ref_depth_files = natsorted(list(ref_depth_folder.glob("*.png")))
assert len(ref_rgb_files) == ref_poses.shape[0]
print(f"ref poses: {ref_poses.shape}")

query_poses_file = query_scene_folder / "poses_camera_right_tum.txt"
query_poses = load_tum_poses(query_poses_file, PoseMode.TUM)
query_rgb_folder = query_scene_folder / "image_right"
query_rgb_files = natsorted(list(query_rgb_folder.glob("*.png")))

RESIZE_COMMON = [512, 288]
intrinsics_dicts = read_intrinsics(ref_scene_folder / "intrinsics_right.txt", resize=RESIZE_COMMON)
K_common, W_orig, H_orig = intrinsics_dicts['K3x3'], intrinsics_dicts['width'], intrinsics_dicts['height']
print(f"K:\n{K_common},\nW: {W_orig}, H: {H_orig}")

# subsample query poses
SUBSAMPLE_FACTOR = 10
query_poses = query_poses[::SUBSAMPLE_FACTOR]
print(f"query poses: {query_poses.shape}")

# plot trajectory
plt.figure(figsize=(10, 5))
plt.plot(ref_poses[:, 1], ref_poses[:, 2], label=f"{ref_scene_folder.name}", color='blue')
plt.plot(ref_poses[0, 1], ref_poses[0, 2], 'bo')
plt.plot(ref_poses[-1, 1], ref_poses[-1, 2], 'bx')

plt.plot(query_poses[:, 1], query_poses[:, 2], label=f"{query_scene_folder.name}", color='orange')
plt.plot(query_poses[0, 1], query_poses[0, 2], 'ro')
plt.plot(query_poses[-1, 1], query_poses[-1, 2], 'rx')
plt.legend()
# plt.show()
# save plot
plt.savefig(exp_folder / "trajectory_original.png")
# Out:
# ref poses: (1136, 8)
# Resizing intrinsics by [0.4 0.4]
# K:
# [[245.24022   0.      254.93474]
#  [  0.      245.56148 151.0259 ]
#  [  0.        0.        1.     ]],
# W: 1280.0, H: 720.0
# query poses: (106, 8)

# %%
retrieval_file = exps_root / "asmk-retrievals" / f"{REF_DAY.lower()}-{REF_RUN.replace('_', '').lower()}-query-{QUERY_DAY.lower()}-{QUERY_RUN.replace('_', '').lower()}-asmk" / "query_retrieval_asmk.txt"
# read retrieval file as numpy array
retrieval_data = np.loadtxt(retrieval_file, delimiter=' ')    

# Lists to store filtered poses
retrieved_ref_poses = []
filtered_query_poses = []

# read retrieval file as numpy array
retrieval_data = np.loadtxt(retrieval_file, delimiter=' ')    

# Lists to store filtered poses
retrieved_ref_poses = []
filtered_query_poses = []

for query_pose in tqdm(query_poses):
    query_idx = int(query_pose[0])
    
    query_retrieval = retrieval_data[retrieval_data[:, 0] == query_idx][0]
    ref_idx = int(query_retrieval[1])

    retrieved_ref_poses.append(ref_poses[ref_idx])
    filtered_query_poses.append(query_pose)


# Convert lists to numpy arrays for easier plotting
retrieved_ref_positions = np.array(retrieved_ref_poses)[:, 1:3]  # Assuming the poses are in columns 1 to 3
filtered_query_positions = np.array(filtered_query_poses)[:, 1:3]  # Assuming the poses are in columns 1 to 3

# write poses to file in tum format with timestamps as index
def write_tum_poses(file_path, poses):
    with open(file_path, 'w') as f:
        # simply write the poses as they are
        for pose in poses:
            f.write(" ".join(map(str, pose)) + "\n")

retrieved_ref_poses_file = exp_folder / "retrieved_ref_poses_tum.txt"
filtered_query_poses_file = exp_folder / "filtered_query_poses_tum.txt"

write_tum_poses(retrieved_ref_poses_file, retrieved_ref_poses)
write_tum_poses(filtered_query_poses_file, filtered_query_poses)

print(f"Retrieved ref poses: {len(retrieved_ref_poses)}")

# Plot the query poses and retrieved reference poses
plt.figure(figsize=(10, 6))

plt.plot(retrieved_ref_positions[:, 0], retrieved_ref_positions[:, 1], 'bo-', label='Retrieved Reference Poses')
plt.plot(filtered_query_positions[:, 0], filtered_query_positions[:, 1], 'o-', color='orange', label='Filtered Query Poses')
plt.xlabel('X')
plt.ylabel('Y')
plt.title(f'Query Poses and Retrieved Reference Poses {len(retrieved_ref_poses)}') 
plt.legend()

# plt.show()
plt.savefig(exp_folder / "trajectory_filtered.png")
# Out:
# 100%|██████████| 106/106 [00:00<00:00, 102773.05it/s]
# Retrieved ref poses: 106

# %%
from mast3r_src.model import AsymmetricMASt3R

from dust3r_src.dust3r.inference import inference
from dust3r_src.dust3r.utils.image import load_images

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f'Using device: {device}')

model_name = "./checkpoints/mast3r/MASt3R_ViTLarge_BaseDecoder_512_catmlpdpt_metric.pth"
model = AsymmetricMASt3R.from_pretrained(model_name).to(device) # 3.178 GB model
# Out:
# /scratch/public_scratch/toponav/miniconda3/envs/mast3r/lib/python3.11/site-packages/torchvision/io/image.py:13: UserWarning: Failed to load image Python extension: '/scratch/public_scratch/toponav/miniconda3/envs/mast3r/lib/python3.11/site-packages/torchvision/image.so: undefined symbol: _ZN3c1017RegisterOperatorsD1Ev'If you don't plan on using image functionality from `torchvision.io`, you can ignore this warning. Otherwise, there might be something wrong with your environment. Did you have `libjpeg` or `libpng` installed before building `torchvision` from source?
#   warn(
# Using device: cuda
# ... loading model from ./checkpoints/mast3r/MASt3R_ViTLarge_BaseDecoder_512_catmlpdpt_metric.pth
# instantiating : AsymmetricMASt3R(enc_depth=24, dec_depth=12, enc_embed_dim=1024, dec_embed_dim=768, enc_num_heads=16, dec_num_heads=12, pos_embed='RoPE100',img_size=(512, 512), head_type='catmlp+dpt', output_mode='pts3d+desc24', depth_mode=('exp', -inf, inf), conf_mode=('exp', 1, inf), patch_embed_cls='PatchEmbedDust3R', two_confs=True, desc_conf_mode=('exp', 0, inf), landscape_only=False)
# <All keys matched successfully>

# %%
import pickle
from mast3r_src.fast_nn import fast_reciprocal_NNs
from src.utils.tf_utils import compose_qt_tf, decompose_tf_qt
from src.utils.pose_solver import PnPSolver, backproject_3d
device = 'cuda'

# make a folder inside exps that will store the inliers and predicted depths
mast3r_inliers_folder = exp_folder / "mast3r_inliers"
mast3r_inliers_folder.mkdir(parents=True, exist_ok=True)


FILTERED_COUNT = len(filtered_query_poses)
pred_poses_list_kitti = []
pred_poses_list_tum = []

for i in range(FILTERED_COUNT):
    image_q_path = query_rgb_files[int(filtered_query_poses[i][0])]
    image_r_path = ref_rgb_files[int(retrieved_ref_poses[i][0])]
    depth_r_path = ref_depth_files[int(retrieved_ref_poses[i][0])]
    
    # depth_im0_sensor = cv2.imread(str(depth_r_path), cv2.IMREAD_UNCHANGED)


    images = load_images([str(image_r_path), str(image_q_path)], size=512)
    output = inference([tuple(images)], model, device, batch_size=1, verbose=False)

    # at this stage, you have the raw dust3r predictions
    view1, pred1 = output['view1'], output['pred1']
    # print(f'view1: {view1["true_shape"]}, pred1: {pred1["desc"].shape}, {pred1["pts3d"].shape}')
    view2, pred2 = output['view2'], output['pred2']

    desc1, desc2 = pred1['desc'].squeeze(0).detach(), pred2['desc'].squeeze(0).detach()

    # find 2D-2D matches between the two images
    matches_im0, matches_im1 = fast_reciprocal_NNs(desc1, desc2, subsample_or_initxy1=8,
                                                    device=device, dist='dot', block_size=2**13)

    # ignore small border around the edge
    H0, W0 = view1['true_shape'][0]
    valid_matches_im0 = (matches_im0[:, 0] >= 3) & (matches_im0[:, 0] < int(W0) - 3) & (
        matches_im0[:, 1] >= 3) & (matches_im0[:, 1] < int(H0) - 3)

    H1, W1 = view2['true_shape'][0]
    valid_matches_im1 = (matches_im1[:, 0] >= 3) & (matches_im1[:, 0] < int(W1) - 3) & (
        matches_im1[:, 1] >= 3) & (matches_im1[:, 1] < int(H1) - 3)

    valid_matches = valid_matches_im0 & valid_matches_im1
    matches_im0, matches_im1 = matches_im0[valid_matches], matches_im1[valid_matches]

    # 1. read from sensor
    # depth_im0 = depth_im0_sensor.astype(np.float32) / 1000.0
    # 2. use from mast3r
    depth_im0 = pred1['pts3d'][..., 2].squeeze(0).cpu().numpy()

    # run PnP solver
    solver = PnPSolver()
    R, t, inliers, reproj_errs = solver.estimate_pose(matches_im0, matches_im1, depth_im0, K_common)
    
    # reference tranform
    retrieved_ref_pose = retrieved_ref_poses[i]
    qvec_w2ref = retrieved_ref_pose[4:]
    tvec_w2ref = retrieved_ref_pose[1:4]
    timestamp = retrieved_ref_pose[0]
    tf_w2ref= compose_qt_tf(qvec_w2ref, tvec_w2ref, in_xyzw=True)
    
    if np.isnan(R).any():
        T_w2query =  np.eye(4)
        inliers = np.array([])
        reproj_errs = np.array([])
    else:
        tf_query2ref = np.eye(4)
        tf_query2ref[:3, :3] = R
        tf_query2ref[:3, 3] = t.squeeze()

        # save inlier matches and corresponding pts3d
        sorted_indices = np.argsort(reproj_errs[inliers].flatten())
        inliers = inliers[sorted_indices]
        reproj_errs = reproj_errs[inliers]
        matches_im0_inliers, matches_im1_inliers = matches_im0[inliers], matches_im1[inliers]
        depth_inliers = depth_im0[matches_im0_inliers[:, 1].astype(int), matches_im0_inliers[:, 0].astype(int)]
        xyz_0_inliers = backproject_3d(matches_im0_inliers, depth_inliers, K_common)

        inliers_file = mast3r_inliers_folder / f"query_{int(filtered_query_poses[i][0])}_inliers.pkl"
        H0W0, H1W1 = tuple(map(int, (H_orig, W_orig))), tuple(map(int, (H_orig, W_orig)))
        H0W0_RESIZE, H1W1_RESIZE = RESIZE_COMMON[::-1], RESIZE_COMMON[::-1]
        
        with open(inliers_file, 'wb') as f:
            pickle.dump({'matches_im0': matches_im0_inliers, 'matches_im1': matches_im1_inliers, 'xyz_0': xyz_0_inliers,
                            'H0W0': H0W0, 'H1W1': H1W1, 'H0W0_RESIZE': H0W0_RESIZE, 'H1W1_RESIZE': H1W1_RESIZE}, f)
        print(f"> Saved inliers to {inliers_file}")

        # transform from current reference (relative) to global by multiplying with reference pose
        T_w2query =  tf_w2ref @ np.linalg.inv(tf_query2ref)
    
    quat_w2query, tvec_w2query = decompose_tf_qt(T_w2query, in_xyzw=True)
    
    pred_poses_list_tum.append([timestamp, *tvec_w2query, *quat_w2query])

pred_poses_tum = np.array(pred_poses_list_tum)
pred_poses_file_tum = exp_folder / 'pred_poses_tum_query_down.txt'
write_tum_poses(pred_poses_file_tum, pred_poses_tum)
print(f'> Saved GT camera poses to {pred_poses_file_tum}')
# Out:
# >> Loading a list of 2 images
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun15/Aisle_CCW_Run_1/image_right/000043.png with resolution 1280x720 --> 512x288
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun23/Aisle_CW_Run_2/image_right/000000.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# /home/onyx/work_dirs/rjayanti/mast3r-vloc/dust3r_src/dust3r/inference.py:48: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=bool(use_amp)):
# /home/onyx/work_dirs/rjayanti/mast3r-vloc/dust3r_src/dust3r/model.py:205: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=False):
# /home/onyx/work_dirs/rjayanti/mast3r-vloc/dust3r_src/dust3r/inference.py:52: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=False):
# > Saved inliers to results/mast3rvloc-torwic/jun15-aisleccwrun1-query-jun23-aislecwrun2-asmk-retrieval/mast3r_inliers/query_0_inliers.pkl
# >> Loading a list of 2 images
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun15/Aisle_CCW_Run_1/image_right/000043.png with resolution 1280x720 --> 512x288
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun23/Aisle_CW_Run_2/image_right/000010.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-torwic/jun15-aisleccwrun1-query-jun23-aislecwrun2-asmk-retrieval/mast3r_inliers/query_10_inliers.pkl
# >> Loading a list of 2 images
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun15/Aisle_CCW_Run_1/image_right/000043.png with resolution 1280x720 --> 512x288
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun23/Aisle_CW_Run_2/image_right/000020.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-torwic/jun15-aisleccwrun1-query-jun23-aislecwrun2-asmk-retrieval/mast3r_inliers/query_20_inliers.pkl
# >> Loading a list of 2 images
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun15/Aisle_CCW_Run_1/image_right/000042.png with resolution 1280x720 --> 512x288
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun23/Aisle_CW_Run_2/image_right/000030.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-torwic/jun15-aisleccwrun1-query-jun23-aislecwrun2-asmk-retrieval/mast3r_inliers/query_30_inliers.pkl
# >> Loading a list of 2 images
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun15/Aisle_CCW_Run_1/image_right/000042.png with resolution 1280x720 --> 512x288
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun23/Aisle_CW_Run_2/image_right/000040.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-torwic/jun15-aisleccwrun1-query-jun23-aislecwrun2-asmk-retrieval/mast3r_inliers/query_40_inliers.pkl
# >> Loading a list of 2 images
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun15/Aisle_CCW_Run_1/image_right/000054.png with resolution 1280x720 --> 512x288
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun23/Aisle_CW_Run_2/image_right/000050.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-torwic/jun15-aisleccwrun1-query-jun23-aislecwrun2-asmk-retrieval/mast3r_inliers/query_50_inliers.pkl
# >> Loading a list of 2 images
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun15/Aisle_CCW_Run_1/image_right/000064.png with resolution 1280x720 --> 512x288
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun23/Aisle_CW_Run_2/image_right/000060.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-torwic/jun15-aisleccwrun1-query-jun23-aislecwrun2-asmk-retrieval/mast3r_inliers/query_60_inliers.pkl
# >> Loading a list of 2 images
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun15/Aisle_CCW_Run_1/image_right/000075.png with resolution 1280x720 --> 512x288
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun23/Aisle_CW_Run_2/image_right/000070.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-torwic/jun15-aisleccwrun1-query-jun23-aislecwrun2-asmk-retrieval/mast3r_inliers/query_70_inliers.pkl
# >> Loading a list of 2 images
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun15/Aisle_CCW_Run_1/image_right/000083.png with resolution 1280x720 --> 512x288
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun23/Aisle_CW_Run_2/image_right/000080.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-torwic/jun15-aisleccwrun1-query-jun23-aislecwrun2-asmk-retrieval/mast3r_inliers/query_80_inliers.pkl
# >> Loading a list of 2 images
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun15/Aisle_CCW_Run_1/image_right/000099.png with resolution 1280x720 --> 512x288
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun23/Aisle_CW_Run_2/image_right/000090.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-torwic/jun15-aisleccwrun1-query-jun23-aislecwrun2-asmk-retrieval/mast3r_inliers/query_90_inliers.pkl
# >> Loading a list of 2 images
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun15/Aisle_CCW_Run_1/image_right/000112.png with resolution 1280x720 --> 512x288
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun23/Aisle_CW_Run_2/image_right/000100.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-torwic/jun15-aisleccwrun1-query-jun23-aislecwrun2-asmk-retrieval/mast3r_inliers/query_100_inliers.pkl
# >> Loading a list of 2 images
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun15/Aisle_CCW_Run_1/image_right/000126.png with resolution 1280x720 --> 512x288
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun23/Aisle_CW_Run_2/image_right/000110.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-torwic/jun15-aisleccwrun1-query-jun23-aislecwrun2-asmk-retrieval/mast3r_inliers/query_110_inliers.pkl
# >> Loading a list of 2 images
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun15/Aisle_CCW_Run_1/image_right/000162.png with resolution 1280x720 --> 512x288
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun23/Aisle_CW_Run_2/image_right/000120.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-torwic/jun15-aisleccwrun1-query-jun23-aislecwrun2-asmk-retrieval/mast3r_inliers/query_120_inliers.pkl
# >> Loading a list of 2 images
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun15/Aisle_CCW_Run_1/image_right/000206.png with resolution 1280x720 --> 512x288
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun23/Aisle_CW_Run_2/image_right/000130.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-torwic/jun15-aisleccwrun1-query-jun23-aislecwrun2-asmk-retrieval/mast3r_inliers/query_130_inliers.pkl
# >> Loading a list of 2 images
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun15/Aisle_CCW_Run_1/image_right/000206.png with resolution 1280x720 --> 512x288
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun23/Aisle_CW_Run_2/image_right/000140.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-torwic/jun15-aisleccwrun1-query-jun23-aislecwrun2-asmk-retrieval/mast3r_inliers/query_140_inliers.pkl
# >> Loading a list of 2 images
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun15/Aisle_CCW_Run_1/image_right/000226.png with resolution 1280x720 --> 512x288
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun23/Aisle_CW_Run_2/image_right/000150.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-torwic/jun15-aisleccwrun1-query-jun23-aislecwrun2-asmk-retrieval/mast3r_inliers/query_150_inliers.pkl
# >> Loading a list of 2 images
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun15/Aisle_CCW_Run_1/image_right/000233.png with resolution 1280x720 --> 512x288
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun23/Aisle_CW_Run_2/image_right/000160.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-torwic/jun15-aisleccwrun1-query-jun23-aislecwrun2-asmk-retrieval/mast3r_inliers/query_160_inliers.pkl
# >> Loading a list of 2 images
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun15/Aisle_CCW_Run_1/image_right/000247.png with resolution 1280x720 --> 512x288
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun23/Aisle_CW_Run_2/image_right/000170.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-torwic/jun15-aisleccwrun1-query-jun23-aislecwrun2-asmk-retrieval/mast3r_inliers/query_170_inliers.pkl
# >> Loading a list of 2 images
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun15/Aisle_CCW_Run_1/image_right/000266.png with resolution 1280x720 --> 512x288
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun23/Aisle_CW_Run_2/image_right/000180.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-torwic/jun15-aisleccwrun1-query-jun23-aislecwrun2-asmk-retrieval/mast3r_inliers/query_180_inliers.pkl
# >> Loading a list of 2 images
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun15/Aisle_CCW_Run_1/image_right/000272.png with resolution 1280x720 --> 512x288
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun23/Aisle_CW_Run_2/image_right/000190.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-torwic/jun15-aisleccwrun1-query-jun23-aislecwrun2-asmk-retrieval/mast3r_inliers/query_190_inliers.pkl
# >> Loading a list of 2 images
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun15/Aisle_CCW_Run_1/image_right/000286.png with resolution 1280x720 --> 512x288
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun23/Aisle_CW_Run_2/image_right/000200.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-torwic/jun15-aisleccwrun1-query-jun23-aislecwrun2-asmk-retrieval/mast3r_inliers/query_200_inliers.pkl
# >> Loading a list of 2 images
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun15/Aisle_CCW_Run_1/image_right/000295.png with resolution 1280x720 --> 512x288
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun23/Aisle_CW_Run_2/image_right/000210.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-torwic/jun15-aisleccwrun1-query-jun23-aislecwrun2-asmk-retrieval/mast3r_inliers/query_210_inliers.pkl
# >> Loading a list of 2 images
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun15/Aisle_CCW_Run_1/image_right/000296.png with resolution 1280x720 --> 512x288
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun23/Aisle_CW_Run_2/image_right/000220.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-torwic/jun15-aisleccwrun1-query-jun23-aislecwrun2-asmk-retrieval/mast3r_inliers/query_220_inliers.pkl
# >> Loading a list of 2 images
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun15/Aisle_CCW_Run_1/image_right/000313.png with resolution 1280x720 --> 512x288
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun23/Aisle_CW_Run_2/image_right/000230.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-torwic/jun15-aisleccwrun1-query-jun23-aislecwrun2-asmk-retrieval/mast3r_inliers/query_230_inliers.pkl
# >> Loading a list of 2 images
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun15/Aisle_CCW_Run_1/image_right/000296.png with resolution 1280x720 --> 512x288
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun23/Aisle_CW_Run_2/image_right/000240.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-torwic/jun15-aisleccwrun1-query-jun23-aislecwrun2-asmk-retrieval/mast3r_inliers/query_240_inliers.pkl
# >> Loading a list of 2 images
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun15/Aisle_CCW_Run_1/image_right/000322.png with resolution 1280x720 --> 512x288
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun23/Aisle_CW_Run_2/image_right/000250.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-torwic/jun15-aisleccwrun1-query-jun23-aislecwrun2-asmk-retrieval/mast3r_inliers/query_250_inliers.pkl
# >> Loading a list of 2 images
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun15/Aisle_CCW_Run_1/image_right/000312.png with resolution 1280x720 --> 512x288
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun23/Aisle_CW_Run_2/image_right/000260.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-torwic/jun15-aisleccwrun1-query-jun23-aislecwrun2-asmk-retrieval/mast3r_inliers/query_260_inliers.pkl
# >> Loading a list of 2 images
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun15/Aisle_CCW_Run_1/image_right/000312.png with resolution 1280x720 --> 512x288
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun23/Aisle_CW_Run_2/image_right/000270.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-torwic/jun15-aisleccwrun1-query-jun23-aislecwrun2-asmk-retrieval/mast3r_inliers/query_270_inliers.pkl
# >> Loading a list of 2 images
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun15/Aisle_CCW_Run_1/image_right/000303.png with resolution 1280x720 --> 512x288
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun23/Aisle_CW_Run_2/image_right/000280.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-torwic/jun15-aisleccwrun1-query-jun23-aislecwrun2-asmk-retrieval/mast3r_inliers/query_280_inliers.pkl
# >> Loading a list of 2 images
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun15/Aisle_CCW_Run_1/image_right/000312.png with resolution 1280x720 --> 512x288
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun23/Aisle_CW_Run_2/image_right/000290.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-torwic/jun15-aisleccwrun1-query-jun23-aislecwrun2-asmk-retrieval/mast3r_inliers/query_290_inliers.pkl
# >> Loading a list of 2 images
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun15/Aisle_CCW_Run_1/image_right/000296.png with resolution 1280x720 --> 512x288
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun23/Aisle_CW_Run_2/image_right/000300.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-torwic/jun15-aisleccwrun1-query-jun23-aislecwrun2-asmk-retrieval/mast3r_inliers/query_300_inliers.pkl
# >> Loading a list of 2 images
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun15/Aisle_CCW_Run_1/image_right/000386.png with resolution 1280x720 --> 512x288
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun23/Aisle_CW_Run_2/image_right/000310.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-torwic/jun15-aisleccwrun1-query-jun23-aislecwrun2-asmk-retrieval/mast3r_inliers/query_310_inliers.pkl
# >> Loading a list of 2 images
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun15/Aisle_CCW_Run_1/image_right/000320.png with resolution 1280x720 --> 512x288
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun23/Aisle_CW_Run_2/image_right/000320.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-torwic/jun15-aisleccwrun1-query-jun23-aislecwrun2-asmk-retrieval/mast3r_inliers/query_320_inliers.pkl
# >> Loading a list of 2 images
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun15/Aisle_CCW_Run_1/image_right/000308.png with resolution 1280x720 --> 512x288
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun23/Aisle_CW_Run_2/image_right/000330.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-torwic/jun15-aisleccwrun1-query-jun23-aislecwrun2-asmk-retrieval/mast3r_inliers/query_330_inliers.pkl
# >> Loading a list of 2 images
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun15/Aisle_CCW_Run_1/image_right/000306.png with resolution 1280x720 --> 512x288
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun23/Aisle_CW_Run_2/image_right/000340.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-torwic/jun15-aisleccwrun1-query-jun23-aislecwrun2-asmk-retrieval/mast3r_inliers/query_340_inliers.pkl
# >> Loading a list of 2 images
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun15/Aisle_CCW_Run_1/image_right/000308.png with resolution 1280x720 --> 512x288
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun23/Aisle_CW_Run_2/image_right/000350.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-torwic/jun15-aisleccwrun1-query-jun23-aislecwrun2-asmk-retrieval/mast3r_inliers/query_350_inliers.pkl
# >> Loading a list of 2 images
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun15/Aisle_CCW_Run_1/image_right/000664.png with resolution 1280x720 --> 512x288
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun23/Aisle_CW_Run_2/image_right/000360.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-torwic/jun15-aisleccwrun1-query-jun23-aislecwrun2-asmk-retrieval/mast3r_inliers/query_360_inliers.pkl
# >> Loading a list of 2 images
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun15/Aisle_CCW_Run_1/image_right/000452.png with resolution 1280x720 --> 512x288
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun23/Aisle_CW_Run_2/image_right/000370.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-torwic/jun15-aisleccwrun1-query-jun23-aislecwrun2-asmk-retrieval/mast3r_inliers/query_370_inliers.pkl
# >> Loading a list of 2 images
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun15/Aisle_CCW_Run_1/image_right/000816.png with resolution 1280x720 --> 512x288
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun23/Aisle_CW_Run_2/image_right/000380.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# >> Loading a list of 2 images
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun15/Aisle_CCW_Run_1/image_right/000816.png with resolution 1280x720 --> 512x288
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun23/Aisle_CW_Run_2/image_right/000390.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# >> Loading a list of 2 images
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun15/Aisle_CCW_Run_1/image_right/000616.png with resolution 1280x720 --> 512x288
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun23/Aisle_CW_Run_2/image_right/000400.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-torwic/jun15-aisleccwrun1-query-jun23-aislecwrun2-asmk-retrieval/mast3r_inliers/query_400_inliers.pkl
# >> Loading a list of 2 images
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun15/Aisle_CCW_Run_1/image_right/000645.png with resolution 1280x720 --> 512x288
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun23/Aisle_CW_Run_2/image_right/000410.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-torwic/jun15-aisleccwrun1-query-jun23-aislecwrun2-asmk-retrieval/mast3r_inliers/query_410_inliers.pkl
# >> Loading a list of 2 images
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun15/Aisle_CCW_Run_1/image_right/000606.png with resolution 1280x720 --> 512x288
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun23/Aisle_CW_Run_2/image_right/000420.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-torwic/jun15-aisleccwrun1-query-jun23-aislecwrun2-asmk-retrieval/mast3r_inliers/query_420_inliers.pkl
# >> Loading a list of 2 images
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun15/Aisle_CCW_Run_1/image_right/000594.png with resolution 1280x720 --> 512x288
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun23/Aisle_CW_Run_2/image_right/000430.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-torwic/jun15-aisleccwrun1-query-jun23-aislecwrun2-asmk-retrieval/mast3r_inliers/query_430_inliers.pkl
# >> Loading a list of 2 images
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun15/Aisle_CCW_Run_1/image_right/000154.png with resolution 1280x720 --> 512x288
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun23/Aisle_CW_Run_2/image_right/000440.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-torwic/jun15-aisleccwrun1-query-jun23-aislecwrun2-asmk-retrieval/mast3r_inliers/query_440_inliers.pkl
# >> Loading a list of 2 images
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun15/Aisle_CCW_Run_1/image_right/000730.png with resolution 1280x720 --> 512x288
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun23/Aisle_CW_Run_2/image_right/000450.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-torwic/jun15-aisleccwrun1-query-jun23-aislecwrun2-asmk-retrieval/mast3r_inliers/query_450_inliers.pkl
# >> Loading a list of 2 images
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun15/Aisle_CCW_Run_1/image_right/000443.png with resolution 1280x720 --> 512x288
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun23/Aisle_CW_Run_2/image_right/000460.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-torwic/jun15-aisleccwrun1-query-jun23-aislecwrun2-asmk-retrieval/mast3r_inliers/query_460_inliers.pkl
# >> Loading a list of 2 images
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun15/Aisle_CCW_Run_1/image_right/000165.png with resolution 1280x720 --> 512x288
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun23/Aisle_CW_Run_2/image_right/000470.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-torwic/jun15-aisleccwrun1-query-jun23-aislecwrun2-asmk-retrieval/mast3r_inliers/query_470_inliers.pkl
# >> Loading a list of 2 images
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun15/Aisle_CCW_Run_1/image_right/000209.png with resolution 1280x720 --> 512x288
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun23/Aisle_CW_Run_2/image_right/000480.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-torwic/jun15-aisleccwrun1-query-jun23-aislecwrun2-asmk-retrieval/mast3r_inliers/query_480_inliers.pkl
# >> Loading a list of 2 images
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun15/Aisle_CCW_Run_1/image_right/000208.png with resolution 1280x720 --> 512x288
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun23/Aisle_CW_Run_2/image_right/000490.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-torwic/jun15-aisleccwrun1-query-jun23-aislecwrun2-asmk-retrieval/mast3r_inliers/query_490_inliers.pkl
# >> Loading a list of 2 images
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun15/Aisle_CCW_Run_1/image_right/000121.png with resolution 1280x720 --> 512x288
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun23/Aisle_CW_Run_2/image_right/000500.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-torwic/jun15-aisleccwrun1-query-jun23-aislecwrun2-asmk-retrieval/mast3r_inliers/query_500_inliers.pkl
# >> Loading a list of 2 images
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun15/Aisle_CCW_Run_1/image_right/000605.png with resolution 1280x720 --> 512x288
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun23/Aisle_CW_Run_2/image_right/000510.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-torwic/jun15-aisleccwrun1-query-jun23-aislecwrun2-asmk-retrieval/mast3r_inliers/query_510_inliers.pkl
# >> Loading a list of 2 images
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun15/Aisle_CCW_Run_1/image_right/000299.png with resolution 1280x720 --> 512x288
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun23/Aisle_CW_Run_2/image_right/000520.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-torwic/jun15-aisleccwrun1-query-jun23-aislecwrun2-asmk-retrieval/mast3r_inliers/query_520_inliers.pkl
# >> Loading a list of 2 images
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun15/Aisle_CCW_Run_1/image_right/000297.png with resolution 1280x720 --> 512x288
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun23/Aisle_CW_Run_2/image_right/000530.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-torwic/jun15-aisleccwrun1-query-jun23-aislecwrun2-asmk-retrieval/mast3r_inliers/query_530_inliers.pkl
# >> Loading a list of 2 images
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun15/Aisle_CCW_Run_1/image_right/000306.png with resolution 1280x720 --> 512x288
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun23/Aisle_CW_Run_2/image_right/000540.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-torwic/jun15-aisleccwrun1-query-jun23-aislecwrun2-asmk-retrieval/mast3r_inliers/query_540_inliers.pkl
# >> Loading a list of 2 images
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun15/Aisle_CCW_Run_1/image_right/000306.png with resolution 1280x720 --> 512x288
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun23/Aisle_CW_Run_2/image_right/000550.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-torwic/jun15-aisleccwrun1-query-jun23-aislecwrun2-asmk-retrieval/mast3r_inliers/query_550_inliers.pkl
# >> Loading a list of 2 images
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun15/Aisle_CCW_Run_1/image_right/000325.png with resolution 1280x720 --> 512x288
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun23/Aisle_CW_Run_2/image_right/000560.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-torwic/jun15-aisleccwrun1-query-jun23-aislecwrun2-asmk-retrieval/mast3r_inliers/query_560_inliers.pkl
# >> Loading a list of 2 images
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun15/Aisle_CCW_Run_1/image_right/000339.png with resolution 1280x720 --> 512x288
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun23/Aisle_CW_Run_2/image_right/000570.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-torwic/jun15-aisleccwrun1-query-jun23-aislecwrun2-asmk-retrieval/mast3r_inliers/query_570_inliers.pkl
# >> Loading a list of 2 images
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun15/Aisle_CCW_Run_1/image_right/000366.png with resolution 1280x720 --> 512x288
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun23/Aisle_CW_Run_2/image_right/000580.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-torwic/jun15-aisleccwrun1-query-jun23-aislecwrun2-asmk-retrieval/mast3r_inliers/query_580_inliers.pkl
# >> Loading a list of 2 images
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun15/Aisle_CCW_Run_1/image_right/000325.png with resolution 1280x720 --> 512x288
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun23/Aisle_CW_Run_2/image_right/000590.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-torwic/jun15-aisleccwrun1-query-jun23-aislecwrun2-asmk-retrieval/mast3r_inliers/query_590_inliers.pkl
# >> Loading a list of 2 images
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun15/Aisle_CCW_Run_1/image_right/000307.png with resolution 1280x720 --> 512x288
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun23/Aisle_CW_Run_2/image_right/000600.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-torwic/jun15-aisleccwrun1-query-jun23-aislecwrun2-asmk-retrieval/mast3r_inliers/query_600_inliers.pkl
# >> Loading a list of 2 images
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun15/Aisle_CCW_Run_1/image_right/000321.png with resolution 1280x720 --> 512x288
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun23/Aisle_CW_Run_2/image_right/000610.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-torwic/jun15-aisleccwrun1-query-jun23-aislecwrun2-asmk-retrieval/mast3r_inliers/query_610_inliers.pkl
# >> Loading a list of 2 images
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun15/Aisle_CCW_Run_1/image_right/000304.png with resolution 1280x720 --> 512x288
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun23/Aisle_CW_Run_2/image_right/000620.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-torwic/jun15-aisleccwrun1-query-jun23-aislecwrun2-asmk-retrieval/mast3r_inliers/query_620_inliers.pkl
# >> Loading a list of 2 images
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun15/Aisle_CCW_Run_1/image_right/000313.png with resolution 1280x720 --> 512x288
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun23/Aisle_CW_Run_2/image_right/000630.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-torwic/jun15-aisleccwrun1-query-jun23-aislecwrun2-asmk-retrieval/mast3r_inliers/query_630_inliers.pkl
# >> Loading a list of 2 images
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun15/Aisle_CCW_Run_1/image_right/000344.png with resolution 1280x720 --> 512x288
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun23/Aisle_CW_Run_2/image_right/000640.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-torwic/jun15-aisleccwrun1-query-jun23-aislecwrun2-asmk-retrieval/mast3r_inliers/query_640_inliers.pkl
# >> Loading a list of 2 images
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun15/Aisle_CCW_Run_1/image_right/000338.png with resolution 1280x720 --> 512x288
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun23/Aisle_CW_Run_2/image_right/000650.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-torwic/jun15-aisleccwrun1-query-jun23-aislecwrun2-asmk-retrieval/mast3r_inliers/query_650_inliers.pkl
# >> Loading a list of 2 images
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun15/Aisle_CCW_Run_1/image_right/000724.png with resolution 1280x720 --> 512x288
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun23/Aisle_CW_Run_2/image_right/000660.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-torwic/jun15-aisleccwrun1-query-jun23-aislecwrun2-asmk-retrieval/mast3r_inliers/query_660_inliers.pkl
# >> Loading a list of 2 images
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun15/Aisle_CCW_Run_1/image_right/000352.png with resolution 1280x720 --> 512x288
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun23/Aisle_CW_Run_2/image_right/000670.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-torwic/jun15-aisleccwrun1-query-jun23-aislecwrun2-asmk-retrieval/mast3r_inliers/query_670_inliers.pkl
# >> Loading a list of 2 images
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun15/Aisle_CCW_Run_1/image_right/000359.png with resolution 1280x720 --> 512x288
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun23/Aisle_CW_Run_2/image_right/000680.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-torwic/jun15-aisleccwrun1-query-jun23-aislecwrun2-asmk-retrieval/mast3r_inliers/query_680_inliers.pkl
# >> Loading a list of 2 images
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun15/Aisle_CCW_Run_1/image_right/000746.png with resolution 1280x720 --> 512x288
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun23/Aisle_CW_Run_2/image_right/000690.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-torwic/jun15-aisleccwrun1-query-jun23-aislecwrun2-asmk-retrieval/mast3r_inliers/query_690_inliers.pkl
# >> Loading a list of 2 images
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun15/Aisle_CCW_Run_1/image_right/000746.png with resolution 1280x720 --> 512x288
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun23/Aisle_CW_Run_2/image_right/000700.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-torwic/jun15-aisleccwrun1-query-jun23-aislecwrun2-asmk-retrieval/mast3r_inliers/query_700_inliers.pkl
# >> Loading a list of 2 images
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun15/Aisle_CCW_Run_1/image_right/000746.png with resolution 1280x720 --> 512x288
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun23/Aisle_CW_Run_2/image_right/000710.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-torwic/jun15-aisleccwrun1-query-jun23-aislecwrun2-asmk-retrieval/mast3r_inliers/query_710_inliers.pkl
# >> Loading a list of 2 images
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun15/Aisle_CCW_Run_1/image_right/000799.png with resolution 1280x720 --> 512x288
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun23/Aisle_CW_Run_2/image_right/000720.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-torwic/jun15-aisleccwrun1-query-jun23-aislecwrun2-asmk-retrieval/mast3r_inliers/query_720_inliers.pkl
# >> Loading a list of 2 images
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun15/Aisle_CCW_Run_1/image_right/000811.png with resolution 1280x720 --> 512x288
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun23/Aisle_CW_Run_2/image_right/000730.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-torwic/jun15-aisleccwrun1-query-jun23-aislecwrun2-asmk-retrieval/mast3r_inliers/query_730_inliers.pkl
# >> Loading a list of 2 images
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun15/Aisle_CCW_Run_1/image_right/000343.png with resolution 1280x720 --> 512x288
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun23/Aisle_CW_Run_2/image_right/000740.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-torwic/jun15-aisleccwrun1-query-jun23-aislecwrun2-asmk-retrieval/mast3r_inliers/query_740_inliers.pkl
# >> Loading a list of 2 images
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun15/Aisle_CCW_Run_1/image_right/000827.png with resolution 1280x720 --> 512x288
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun23/Aisle_CW_Run_2/image_right/000750.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-torwic/jun15-aisleccwrun1-query-jun23-aislecwrun2-asmk-retrieval/mast3r_inliers/query_750_inliers.pkl
# >> Loading a list of 2 images
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun15/Aisle_CCW_Run_1/image_right/000843.png with resolution 1280x720 --> 512x288
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun23/Aisle_CW_Run_2/image_right/000760.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-torwic/jun15-aisleccwrun1-query-jun23-aislecwrun2-asmk-retrieval/mast3r_inliers/query_760_inliers.pkl
# >> Loading a list of 2 images
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun15/Aisle_CCW_Run_1/image_right/000848.png with resolution 1280x720 --> 512x288
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun23/Aisle_CW_Run_2/image_right/000770.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-torwic/jun15-aisleccwrun1-query-jun23-aislecwrun2-asmk-retrieval/mast3r_inliers/query_770_inliers.pkl
# >> Loading a list of 2 images
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun15/Aisle_CCW_Run_1/image_right/000868.png with resolution 1280x720 --> 512x288
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun23/Aisle_CW_Run_2/image_right/000780.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-torwic/jun15-aisleccwrun1-query-jun23-aislecwrun2-asmk-retrieval/mast3r_inliers/query_780_inliers.pkl
# >> Loading a list of 2 images
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun15/Aisle_CCW_Run_1/image_right/000868.png with resolution 1280x720 --> 512x288
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun23/Aisle_CW_Run_2/image_right/000790.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-torwic/jun15-aisleccwrun1-query-jun23-aislecwrun2-asmk-retrieval/mast3r_inliers/query_790_inliers.pkl
# >> Loading a list of 2 images
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun15/Aisle_CCW_Run_1/image_right/000906.png with resolution 1280x720 --> 512x288
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun23/Aisle_CW_Run_2/image_right/000800.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-torwic/jun15-aisleccwrun1-query-jun23-aislecwrun2-asmk-retrieval/mast3r_inliers/query_800_inliers.pkl
# >> Loading a list of 2 images
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun15/Aisle_CCW_Run_1/image_right/000906.png with resolution 1280x720 --> 512x288
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun23/Aisle_CW_Run_2/image_right/000810.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-torwic/jun15-aisleccwrun1-query-jun23-aislecwrun2-asmk-retrieval/mast3r_inliers/query_810_inliers.pkl
# >> Loading a list of 2 images
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun15/Aisle_CCW_Run_1/image_right/000909.png with resolution 1280x720 --> 512x288
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun23/Aisle_CW_Run_2/image_right/000820.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-torwic/jun15-aisleccwrun1-query-jun23-aislecwrun2-asmk-retrieval/mast3r_inliers/query_820_inliers.pkl
# >> Loading a list of 2 images
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun15/Aisle_CCW_Run_1/image_right/000878.png with resolution 1280x720 --> 512x288
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun23/Aisle_CW_Run_2/image_right/000830.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-torwic/jun15-aisleccwrun1-query-jun23-aislecwrun2-asmk-retrieval/mast3r_inliers/query_830_inliers.pkl
# >> Loading a list of 2 images
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun15/Aisle_CCW_Run_1/image_right/000911.png with resolution 1280x720 --> 512x288
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun23/Aisle_CW_Run_2/image_right/000840.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-torwic/jun15-aisleccwrun1-query-jun23-aislecwrun2-asmk-retrieval/mast3r_inliers/query_840_inliers.pkl
# >> Loading a list of 2 images
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun15/Aisle_CCW_Run_1/image_right/000911.png with resolution 1280x720 --> 512x288
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun23/Aisle_CW_Run_2/image_right/000850.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-torwic/jun15-aisleccwrun1-query-jun23-aislecwrun2-asmk-retrieval/mast3r_inliers/query_850_inliers.pkl
# >> Loading a list of 2 images
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun15/Aisle_CCW_Run_1/image_right/000907.png with resolution 1280x720 --> 512x288
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun23/Aisle_CW_Run_2/image_right/000860.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-torwic/jun15-aisleccwrun1-query-jun23-aislecwrun2-asmk-retrieval/mast3r_inliers/query_860_inliers.pkl
# >> Loading a list of 2 images
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun15/Aisle_CCW_Run_1/image_right/000906.png with resolution 1280x720 --> 512x288
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun23/Aisle_CW_Run_2/image_right/000870.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-torwic/jun15-aisleccwrun1-query-jun23-aislecwrun2-asmk-retrieval/mast3r_inliers/query_870_inliers.pkl
# >> Loading a list of 2 images
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun15/Aisle_CCW_Run_1/image_right/000913.png with resolution 1280x720 --> 512x288
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun23/Aisle_CW_Run_2/image_right/000880.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-torwic/jun15-aisleccwrun1-query-jun23-aislecwrun2-asmk-retrieval/mast3r_inliers/query_880_inliers.pkl
# >> Loading a list of 2 images
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun15/Aisle_CCW_Run_1/image_right/000906.png with resolution 1280x720 --> 512x288
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun23/Aisle_CW_Run_2/image_right/000890.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-torwic/jun15-aisleccwrun1-query-jun23-aislecwrun2-asmk-retrieval/mast3r_inliers/query_890_inliers.pkl
# >> Loading a list of 2 images
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun15/Aisle_CCW_Run_1/image_right/000904.png with resolution 1280x720 --> 512x288
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun23/Aisle_CW_Run_2/image_right/000900.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-torwic/jun15-aisleccwrun1-query-jun23-aislecwrun2-asmk-retrieval/mast3r_inliers/query_900_inliers.pkl
# >> Loading a list of 2 images
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun15/Aisle_CCW_Run_1/image_right/000918.png with resolution 1280x720 --> 512x288
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun23/Aisle_CW_Run_2/image_right/000910.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-torwic/jun15-aisleccwrun1-query-jun23-aislecwrun2-asmk-retrieval/mast3r_inliers/query_910_inliers.pkl
# >> Loading a list of 2 images
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun15/Aisle_CCW_Run_1/image_right/000935.png with resolution 1280x720 --> 512x288
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun23/Aisle_CW_Run_2/image_right/000920.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-torwic/jun15-aisleccwrun1-query-jun23-aislecwrun2-asmk-retrieval/mast3r_inliers/query_920_inliers.pkl
# >> Loading a list of 2 images
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun15/Aisle_CCW_Run_1/image_right/000947.png with resolution 1280x720 --> 512x288
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun23/Aisle_CW_Run_2/image_right/000930.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-torwic/jun15-aisleccwrun1-query-jun23-aislecwrun2-asmk-retrieval/mast3r_inliers/query_930_inliers.pkl
# >> Loading a list of 2 images
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun15/Aisle_CCW_Run_1/image_right/000956.png with resolution 1280x720 --> 512x288
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun23/Aisle_CW_Run_2/image_right/000940.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-torwic/jun15-aisleccwrun1-query-jun23-aislecwrun2-asmk-retrieval/mast3r_inliers/query_940_inliers.pkl
# >> Loading a list of 2 images
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun15/Aisle_CCW_Run_1/image_right/000965.png with resolution 1280x720 --> 512x288
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun23/Aisle_CW_Run_2/image_right/000950.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-torwic/jun15-aisleccwrun1-query-jun23-aislecwrun2-asmk-retrieval/mast3r_inliers/query_950_inliers.pkl
# >> Loading a list of 2 images
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun15/Aisle_CCW_Run_1/image_right/000967.png with resolution 1280x720 --> 512x288
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun23/Aisle_CW_Run_2/image_right/000960.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-torwic/jun15-aisleccwrun1-query-jun23-aislecwrun2-asmk-retrieval/mast3r_inliers/query_960_inliers.pkl
# >> Loading a list of 2 images
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun15/Aisle_CCW_Run_1/image_right/000968.png with resolution 1280x720 --> 512x288
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun23/Aisle_CW_Run_2/image_right/000970.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-torwic/jun15-aisleccwrun1-query-jun23-aislecwrun2-asmk-retrieval/mast3r_inliers/query_970_inliers.pkl
# >> Loading a list of 2 images
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun15/Aisle_CCW_Run_1/image_right/000970.png with resolution 1280x720 --> 512x288
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun23/Aisle_CW_Run_2/image_right/000980.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-torwic/jun15-aisleccwrun1-query-jun23-aislecwrun2-asmk-retrieval/mast3r_inliers/query_980_inliers.pkl
# >> Loading a list of 2 images
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun15/Aisle_CCW_Run_1/image_right/001048.png with resolution 1280x720 --> 512x288
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun23/Aisle_CW_Run_2/image_right/000990.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-torwic/jun15-aisleccwrun1-query-jun23-aislecwrun2-asmk-retrieval/mast3r_inliers/query_990_inliers.pkl
# >> Loading a list of 2 images
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun15/Aisle_CCW_Run_1/image_right/001049.png with resolution 1280x720 --> 512x288
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun23/Aisle_CW_Run_2/image_right/001000.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-torwic/jun15-aisleccwrun1-query-jun23-aislecwrun2-asmk-retrieval/mast3r_inliers/query_1000_inliers.pkl
# >> Loading a list of 2 images
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun15/Aisle_CCW_Run_1/image_right/001061.png with resolution 1280x720 --> 512x288
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun23/Aisle_CW_Run_2/image_right/001010.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-torwic/jun15-aisleccwrun1-query-jun23-aislecwrun2-asmk-retrieval/mast3r_inliers/query_1010_inliers.pkl
# >> Loading a list of 2 images
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun15/Aisle_CCW_Run_1/image_right/001066.png with resolution 1280x720 --> 512x288
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun23/Aisle_CW_Run_2/image_right/001020.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-torwic/jun15-aisleccwrun1-query-jun23-aislecwrun2-asmk-retrieval/mast3r_inliers/query_1020_inliers.pkl
# >> Loading a list of 2 images
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun15/Aisle_CCW_Run_1/image_right/001079.png with resolution 1280x720 --> 512x288
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun23/Aisle_CW_Run_2/image_right/001030.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-torwic/jun15-aisleccwrun1-query-jun23-aislecwrun2-asmk-retrieval/mast3r_inliers/query_1030_inliers.pkl
# >> Loading a list of 2 images
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun15/Aisle_CCW_Run_1/image_right/001125.png with resolution 1280x720 --> 512x288
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun23/Aisle_CW_Run_2/image_right/001040.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-torwic/jun15-aisleccwrun1-query-jun23-aislecwrun2-asmk-retrieval/mast3r_inliers/query_1040_inliers.pkl
# >> Loading a list of 2 images
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun15/Aisle_CCW_Run_1/image_right/000046.png with resolution 1280x720 --> 512x288
#  - adding /home/onyx/work_dirs/rjayanti/mast3r-vloc/data/TorWIC-SLAM/Jun23/Aisle_CW_Run_2/image_right/001050.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-torwic/jun15-aisleccwrun1-query-jun23-aislecwrun2-asmk-retrieval/mast3r_inliers/query_1050_inliers.pkl
# > Saved GT camera poses to results/mast3rvloc-torwic/jun15-aisleccwrun1-query-jun23-aislecwrun2-asmk-retrieval/pred_poses_tum_query_down.txt

# %%
tum_mapping = file_interface.read_tum_trajectory_file(retrieved_ref_poses_file)
tum_query_gt = file_interface.read_tum_trajectory_file(filtered_query_poses_file)
tum_query_pred = file_interface.read_tum_trajectory_file(pred_poses_file_tum)

fig = plt.figure(figsize=(10, 20))
traj_by_label = {
    # "mapping_run": tum_mapping, 
    "query_run_gt": tum_query_gt,
    "query_run_pred": tum_query_pred,
}

plot.trajectories(fig, traj_by_label, plot.PlotMode.xy, plot_start_end_markers=True)
# plt.show()
plt.savefig(exp_folder / "trajectory_comparison.png")

# %%
import json
pose_relation = metrics.PoseRelation.translation_part
data = (tum_query_gt, tum_query_pred)

ape_metric = metrics.APE(pose_relation)
ape_metric.process_data(data)

ape_stats = ape_metric.get_all_statistics()
pprint.pprint(ape_stats)
# save ape stats as json
ape_stats_file = exp_folder / "ape_stats.json"
with open(ape_stats_file, 'w') as f:
    json.dump(ape_stats, f, indent=4)

fig = plt.figure()
plot.error_array(fig.gca(), ape_metric.error,
                statistics={s:v for s,v in ape_stats.items() if s != "sse"},
                name="APE", title="APE w.r.t. " + ape_metric.pose_relation.value, xlabel="$t$ (s)")
# plt.show()
plt.savefig(exp_folder / "trajectory_ape.png")
# Out:
# {'max': 29.327515540851813,
#  'mean': 5.102635860009499,
#  'median': 2.7688708718377852,
#  'min': 0.03827861102209922,
#  'rmse': 8.551166547302687,
#  'sse': 7750.979627889108,
#  'std': 6.861891619652243}

# %%
plot_mode = plot.PlotMode.xy
fig = plt.figure(figsize=(15, 5))
ax = plot.prepare_axis(fig, plot_mode)
plot.traj(ax, plot_mode, tum_mapping, '--', "gray", "gt_query")
plot.traj_colormap(ax, tum_query_pred, ape_metric.error, plot_mode, min_map=ape_stats["min"], max_map=ape_stats["max"])
ax.legend()
# plt.show()
plt.savefig(exp_folder / "trajectory_ape_colormap.png")
