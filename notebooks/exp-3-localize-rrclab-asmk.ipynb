# %%
import shutil
from tqdm import tqdm
from pathlib import Path
from natsort import natsorted

import cv2
import torch
import numpy as np
import matplotlib.pyplot as plt

# set plt to ioff
plt.ioff()

# for evo ######################################################################
from evo.tools import log
log.configure_logging(verbose=False, debug=False, silent=False)

import pprint
import numpy as np

from evo.tools import plot
import matplotlib.pyplot as plt

# temporarily override some package settings
from evo.tools.settings import SETTINGS
SETTINGS.plot_usetex = False

plot.apply_settings(SETTINGS)
# %matplotlib inline

from evo.tools import file_interface
from evo.core import metrics
from evo.core.units import Unit
#############################################################################

# reload notebook automatically after changes to source python files
# %load_ext autoreload
# %autoreload 2

# change base folder to parent
import os
if os.path.basename(os.getcwd()) == 'notebooks':
    os.chdir('..')
print(os.getcwd())

# Set CUDA_VISIBLE_DEVICES
os.environ['CUDA_VISIBLE_DEVICES'] = '1'
# Out:
# /home/onyx/work_dirs/rjayanti/mast3r-vloc

# %%
from src.datasets.dataset_utils import read_intrinsics, load_tum_poses, PoseMode

dataset_root = Path("data/rrc-lab-data/wheelchair-runs-20241220/")
exps_root = Path("results/mast3rvloc-rrclab/")

QUERY_RUN = 3

experiment_name = f"run-{QUERY_RUN}-query-asmk-retrieval"

exp_folder = exps_root / experiment_name
exp_folder.mkdir(parents=True, exist_ok=True)

ref_scene_folder = dataset_root / "run-1-wheelchair-mapping"
query_scene_folder = dataset_root / f"run-{QUERY_RUN}-wheelchair-query"

ref_poses_file = ref_scene_folder / "poses_camera_tum.txt"
ref_poses = load_tum_poses(ref_poses_file, PoseMode.TUM)
ref_rgb_folder = ref_scene_folder / "rgb"
ref_rgb_files = natsorted(list(ref_rgb_folder.glob("*.png")))
ref_depth_folder = ref_scene_folder / "aligned_depth"
ref_depth_files = natsorted(list(ref_depth_folder.glob("*.png")))
assert len(ref_rgb_files) == ref_poses.shape[0]
print(f"ref poses: {ref_poses.shape}")

query_poses_file = query_scene_folder / "poses_camera_tum.txt"
query_poses = load_tum_poses(query_poses_file, PoseMode.TUM)
query_rgb_folder = query_scene_folder / "rgb"
query_rgb_files = natsorted(list(query_rgb_folder.glob("*.png")))

RESIZE_COMMON = [512, 288]
intrinsics_dicts = read_intrinsics(ref_scene_folder / "intrinsics.txt", resize=RESIZE_COMMON)
K_common, W_orig, H_orig = intrinsics_dicts['K3x3'], intrinsics_dicts['width'], intrinsics_dicts['height']
print(f"K:\n{K_common},\nW: {W_orig}, H: {H_orig}")

# subsample query poses
SUBSAMPLE_FACTOR = 5
query_poses = query_poses[::SUBSAMPLE_FACTOR]
print(f"query poses: {query_poses.shape}")

# plot trajectory
plt.figure(figsize=(10, 5))
plt.plot(ref_poses[:, 1], ref_poses[:, 2], label=f"{ref_scene_folder.name}", color='blue')
plt.plot(ref_poses[0, 1], ref_poses[0, 2], 'bo')
plt.plot(ref_poses[-1, 1], ref_poses[-1, 2], 'bx')

plt.plot(query_poses[:, 1], query_poses[:, 2], label=f"{query_scene_folder.name}", color='orange')
plt.plot(query_poses[0, 1], query_poses[0, 2], 'ro')
plt.plot(query_poses[-1, 1], query_poses[-1, 2], 'rx')
plt.legend()
# plt.show()
# save plot
plt.savefig(exp_folder / "trajectory_original.png")
# Out:
# ref poses: (2939, 8)
# Resizing intrinsics by [0.4 0.4]
# K:
# [[257.62808   0.      258.38455]
#  [  0.      257.00912 144.67647]
#  [  0.        0.        1.     ]],
# W: 1280.0, H: 720.0
# query poses: (357, 8)

# %%
retrieval_file = exps_root / "asmk-retrievals" / f"run-{QUERY_RUN}-query-rrclab-asmk" / "query_retrieval_asmk.txt"
# read retrieval file as numpy array
retrieval_data = np.loadtxt(retrieval_file, delimiter=' ')    

# Lists to store filtered poses
retrieved_ref_poses = []
filtered_query_poses = []

for query_pose in tqdm(query_poses):
    query_idx = int(query_pose[0])
    
    query_retrieval = retrieval_data[retrieval_data[:, 0] == query_idx][0]
    ref_idx = int(query_retrieval[1])

    retrieved_ref_poses.append(ref_poses[ref_idx])
    filtered_query_poses.append(query_pose)

# Convert lists to numpy arrays for easier plotting
retrieved_ref_positions = np.array(retrieved_ref_poses)[:, 1:3]  # Assuming the poses are in columns 1 to 3
filtered_query_positions = np.array(filtered_query_poses)[:, 1:3]  # Assuming the poses are in columns 1 to 3

# write poses to file in tum format with timestamps as index
def write_tum_poses(file_path, poses):
    with open(file_path, 'w') as f:
        # simply write the poses as they are
        for pose in poses:
            f.write(" ".join(map(str, pose)) + "\n")

retrieved_ref_poses_file = exp_folder / "retrieved_ref_poses_tum.txt"
filtered_query_poses_file = exp_folder / "filtered_query_poses_tum.txt"

write_tum_poses(retrieved_ref_poses_file, retrieved_ref_poses)
write_tum_poses(filtered_query_poses_file, filtered_query_poses)

print(f"Retrieved ref poses: {len(retrieved_ref_poses)}")

# Plot the query poses and retrieved reference poses
plt.figure(figsize=(10, 6))

plt.plot(retrieved_ref_positions[:, 0], retrieved_ref_positions[:, 1], 'bo-', label='Retrieved Reference Poses')
plt.plot(filtered_query_positions[:, 0], filtered_query_positions[:, 1], 'o-', color='orange', label='Filtered Query Poses')
plt.xlabel('X')
plt.ylabel('Y')
plt.title(f'Query Poses and Retrieved Reference Poses {len(retrieved_ref_poses)}')
plt.legend()

# plt.show()
plt.savefig(exp_folder / "trajectory_filtered.png")
# Out:
# 100%|██████████| 357/357 [00:00<00:00, 97459.42it/s]
# Retrieved ref poses: 357

# %%
from mast3r_src.model import AsymmetricMASt3R

from dust3r_src.dust3r.inference import inference
from dust3r_src.dust3r.utils.image import load_images

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f'Using device: {device}')

model_name = "./checkpoints/mast3r/MASt3R_ViTLarge_BaseDecoder_512_catmlpdpt_metric.pth"
model = AsymmetricMASt3R.from_pretrained(model_name).to(device) # 3.178 GB model
# Out:
# /scratch/public_scratch/toponav/miniconda3/envs/mast3r/lib/python3.11/site-packages/torchvision/io/image.py:13: UserWarning: Failed to load image Python extension: '/scratch/public_scratch/toponav/miniconda3/envs/mast3r/lib/python3.11/site-packages/torchvision/image.so: undefined symbol: _ZN3c1017RegisterOperatorsD1Ev'If you don't plan on using image functionality from `torchvision.io`, you can ignore this warning. Otherwise, there might be something wrong with your environment. Did you have `libjpeg` or `libpng` installed before building `torchvision` from source?
#   warn(
# Using device: cuda
# ... loading model from ./checkpoints/mast3r/MASt3R_ViTLarge_BaseDecoder_512_catmlpdpt_metric.pth
# instantiating : AsymmetricMASt3R(enc_depth=24, dec_depth=12, enc_embed_dim=1024, dec_embed_dim=768, enc_num_heads=16, dec_num_heads=12, pos_embed='RoPE100',img_size=(512, 512), head_type='catmlp+dpt', output_mode='pts3d+desc24', depth_mode=('exp', -inf, inf), conf_mode=('exp', 1, inf), patch_embed_cls='PatchEmbedDust3R', two_confs=True, desc_conf_mode=('exp', 0, inf), landscape_only=False)
# <All keys matched successfully>

# %%
import pickle
from mast3r_src.fast_nn import fast_reciprocal_NNs
from src.utils.tf_utils import compose_qt_tf, decompose_tf_qt
from src.utils.pose_solver import PnPSolver, backproject_3d
device = 'cuda'

# make a folder inside exps that will store the inliers and predicted depths
mast3r_inliers_folder = exp_folder / "mast3r_inliers"
mast3r_inliers_folder.mkdir(parents=True, exist_ok=True)


FILTERED_COUNT = len(filtered_query_poses)
pred_poses_list_kitti = []
pred_poses_list_tum = []

for i in range(FILTERED_COUNT):
    image_q_path = query_rgb_files[int(filtered_query_poses[i][0])]
    image_r_path = ref_rgb_files[int(retrieved_ref_poses[i][0])]
    depth_r_path = ref_depth_files[int(retrieved_ref_poses[i][0])]
    
    # depth_im0_sensor = cv2.imread(str(depth_r_path), cv2.IMREAD_UNCHANGED)


    images = load_images([str(image_r_path), str(image_q_path)], size=512)
    output = inference([tuple(images)], model, device, batch_size=1, verbose=False)

    # at this stage, you have the raw dust3r predictions
    view1, pred1 = output['view1'], output['pred1']
    # print(f'view1: {view1["true_shape"]}, pred1: {pred1["desc"].shape}, {pred1["pts3d"].shape}')
    view2, pred2 = output['view2'], output['pred2']

    desc1, desc2 = pred1['desc'].squeeze(0).detach(), pred2['desc'].squeeze(0).detach()

    # find 2D-2D matches between the two images
    matches_im0, matches_im1 = fast_reciprocal_NNs(desc1, desc2, subsample_or_initxy1=8,
                                                    device=device, dist='dot', block_size=2**13)

    # ignore small border around the edge
    H0, W0 = view1['true_shape'][0]
    valid_matches_im0 = (matches_im0[:, 0] >= 3) & (matches_im0[:, 0] < int(W0) - 3) & (
        matches_im0[:, 1] >= 3) & (matches_im0[:, 1] < int(H0) - 3)

    H1, W1 = view2['true_shape'][0]
    valid_matches_im1 = (matches_im1[:, 0] >= 3) & (matches_im1[:, 0] < int(W1) - 3) & (
        matches_im1[:, 1] >= 3) & (matches_im1[:, 1] < int(H1) - 3)

    valid_matches = valid_matches_im0 & valid_matches_im1
    matches_im0, matches_im1 = matches_im0[valid_matches], matches_im1[valid_matches]

    # 1. read from sensor
    # depth_im0 = depth_im0_sensor.astype(np.float32) / 1000.0
    # 2. use from mast3r
    depth_im0 = pred1['pts3d'][..., 2].squeeze(0).cpu().numpy()

    # run PnP solver
    solver = PnPSolver()
    R, t, inliers, reproj_errs = solver.estimate_pose(matches_im0, matches_im1, depth_im0, K_common)
    
    # reference tranform
    retrieved_ref_pose = retrieved_ref_poses[i]
    qvec_w2ref = retrieved_ref_pose[4:]
    tvec_w2ref = retrieved_ref_pose[1:4]
    timestamp = retrieved_ref_pose[0]
    tf_w2ref= compose_qt_tf(qvec_w2ref, tvec_w2ref, in_xyzw=True)
    
    if np.isnan(R).any():
        T_w2query =  np.eye(4)
        inliers = np.array([])
        reproj_errs = np.array([])
    else:
        tf_query2ref = np.eye(4)
        tf_query2ref[:3, :3] = R
        tf_query2ref[:3, 3] = t.squeeze()

        # save inlier matches and corresponding pts3d
        sorted_indices = np.argsort(reproj_errs[inliers].flatten())
        inliers = inliers[sorted_indices]
        reproj_errs = reproj_errs[inliers]
        matches_im0_inliers, matches_im1_inliers = matches_im0[inliers], matches_im1[inliers]
        depth_inliers = depth_im0[matches_im0_inliers[:, 1].astype(int), matches_im0_inliers[:, 0].astype(int)]
        xyz_0_inliers = backproject_3d(matches_im0_inliers, depth_inliers, K_common)

        inliers_file = mast3r_inliers_folder / f"query_{int(filtered_query_poses[i][0])}_inliers.pkl"
        H0W0, H1W1 = tuple(map(int, (H_orig, W_orig))), tuple(map(int, (H_orig, W_orig)))
        H0W0_RESIZE, H1W1_RESIZE = RESIZE_COMMON[::-1], RESIZE_COMMON[::-1]
        
        with open(inliers_file, 'wb') as f:
            pickle.dump({'matches_im0': matches_im0_inliers, 'matches_im1': matches_im1_inliers, 'xyz_0': xyz_0_inliers,
                            'H0W0': H0W0, 'H1W1': H1W1, 'H0W0_RESIZE': H0W0_RESIZE, 'H1W1_RESIZE': H1W1_RESIZE}, f)
        print(f"> Saved inliers to {inliers_file}")

        # transform from current reference (relative) to global by multiplying with reference pose
        T_w2query =  tf_w2ref @ np.linalg.inv(tf_query2ref)
    
    quat_w2query, tvec_w2query = decompose_tf_qt(T_w2query, in_xyzw=True)
    
    pred_poses_list_tum.append([timestamp, *tvec_w2query, *quat_w2query])

pred_poses_tum = np.array(pred_poses_list_tum)
pred_poses_file_tum = exp_folder / 'pred_poses_tum_query_down.txt'
write_tum_poses(pred_poses_file_tum, pred_poses_tum)
print(f'> Saved GT camera poses to {pred_poses_file_tum}')
# Out:
# >> Loading a list of 2 images
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-1-wheelchair-mapping/rgb/2159.png with resolution 1280x720 --> 512x288
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-3-wheelchair-query/rgb/0.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# /home/onyx/work_dirs/rjayanti/mast3r-vloc/dust3r_src/dust3r/inference.py:48: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=bool(use_amp)):
# /home/onyx/work_dirs/rjayanti/mast3r-vloc/dust3r_src/dust3r/model.py:205: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=False):
# /home/onyx/work_dirs/rjayanti/mast3r-vloc/dust3r_src/dust3r/inference.py:52: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=False):
# > Saved inliers to results/mast3rvloc-rrclab/run-3-query-asmk-retrieval/mast3r_inliers/query_0_inliers.pkl
# >> Loading a list of 2 images
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-1-wheelchair-mapping/rgb/2159.png with resolution 1280x720 --> 512x288
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-3-wheelchair-query/rgb/5.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-rrclab/run-3-query-asmk-retrieval/mast3r_inliers/query_5_inliers.pkl
# >> Loading a list of 2 images
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-1-wheelchair-mapping/rgb/2159.png with resolution 1280x720 --> 512x288
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-3-wheelchair-query/rgb/10.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-rrclab/run-3-query-asmk-retrieval/mast3r_inliers/query_10_inliers.pkl
# >> Loading a list of 2 images
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-1-wheelchair-mapping/rgb/2560.png with resolution 1280x720 --> 512x288
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-3-wheelchair-query/rgb/15.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-rrclab/run-3-query-asmk-retrieval/mast3r_inliers/query_15_inliers.pkl
# >> Loading a list of 2 images
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-1-wheelchair-mapping/rgb/2532.png with resolution 1280x720 --> 512x288
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-3-wheelchair-query/rgb/20.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-rrclab/run-3-query-asmk-retrieval/mast3r_inliers/query_20_inliers.pkl
# >> Loading a list of 2 images
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-1-wheelchair-mapping/rgb/2165.png with resolution 1280x720 --> 512x288
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-3-wheelchair-query/rgb/25.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-rrclab/run-3-query-asmk-retrieval/mast3r_inliers/query_25_inliers.pkl
# >> Loading a list of 2 images
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-1-wheelchair-mapping/rgb/2555.png with resolution 1280x720 --> 512x288
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-3-wheelchair-query/rgb/30.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-rrclab/run-3-query-asmk-retrieval/mast3r_inliers/query_30_inliers.pkl
# >> Loading a list of 2 images
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-1-wheelchair-mapping/rgb/2563.png with resolution 1280x720 --> 512x288
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-3-wheelchair-query/rgb/35.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-rrclab/run-3-query-asmk-retrieval/mast3r_inliers/query_35_inliers.pkl
# >> Loading a list of 2 images
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-1-wheelchair-mapping/rgb/2561.png with resolution 1280x720 --> 512x288
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-3-wheelchair-query/rgb/40.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-rrclab/run-3-query-asmk-retrieval/mast3r_inliers/query_40_inliers.pkl
# >> Loading a list of 2 images
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-1-wheelchair-mapping/rgb/2534.png with resolution 1280x720 --> 512x288
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-3-wheelchair-query/rgb/45.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-rrclab/run-3-query-asmk-retrieval/mast3r_inliers/query_45_inliers.pkl
# >> Loading a list of 2 images
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-1-wheelchair-mapping/rgb/2573.png with resolution 1280x720 --> 512x288
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-3-wheelchair-query/rgb/50.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-rrclab/run-3-query-asmk-retrieval/mast3r_inliers/query_50_inliers.pkl
# >> Loading a list of 2 images
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-1-wheelchair-mapping/rgb/2560.png with resolution 1280x720 --> 512x288
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-3-wheelchair-query/rgb/55.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-rrclab/run-3-query-asmk-retrieval/mast3r_inliers/query_55_inliers.pkl
# >> Loading a list of 2 images
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-1-wheelchair-mapping/rgb/2515.png with resolution 1280x720 --> 512x288
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-3-wheelchair-query/rgb/60.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-rrclab/run-3-query-asmk-retrieval/mast3r_inliers/query_60_inliers.pkl
# >> Loading a list of 2 images
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-1-wheelchair-mapping/rgb/2566.png with resolution 1280x720 --> 512x288
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-3-wheelchair-query/rgb/65.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-rrclab/run-3-query-asmk-retrieval/mast3r_inliers/query_65_inliers.pkl
# >> Loading a list of 2 images
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-1-wheelchair-mapping/rgb/2523.png with resolution 1280x720 --> 512x288
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-3-wheelchair-query/rgb/70.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-rrclab/run-3-query-asmk-retrieval/mast3r_inliers/query_70_inliers.pkl
# >> Loading a list of 2 images
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-1-wheelchair-mapping/rgb/2523.png with resolution 1280x720 --> 512x288
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-3-wheelchair-query/rgb/75.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-rrclab/run-3-query-asmk-retrieval/mast3r_inliers/query_75_inliers.pkl
# >> Loading a list of 2 images
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-1-wheelchair-mapping/rgb/2523.png with resolution 1280x720 --> 512x288
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-3-wheelchair-query/rgb/80.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-rrclab/run-3-query-asmk-retrieval/mast3r_inliers/query_80_inliers.pkl
# >> Loading a list of 2 images
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-1-wheelchair-mapping/rgb/2566.png with resolution 1280x720 --> 512x288
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-3-wheelchair-query/rgb/85.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-rrclab/run-3-query-asmk-retrieval/mast3r_inliers/query_85_inliers.pkl
# >> Loading a list of 2 images
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-1-wheelchair-mapping/rgb/2534.png with resolution 1280x720 --> 512x288
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-3-wheelchair-query/rgb/90.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-rrclab/run-3-query-asmk-retrieval/mast3r_inliers/query_90_inliers.pkl
# >> Loading a list of 2 images
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-1-wheelchair-mapping/rgb/2534.png with resolution 1280x720 --> 512x288
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-3-wheelchair-query/rgb/95.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-rrclab/run-3-query-asmk-retrieval/mast3r_inliers/query_95_inliers.pkl
# >> Loading a list of 2 images
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-1-wheelchair-mapping/rgb/2574.png with resolution 1280x720 --> 512x288
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-3-wheelchair-query/rgb/100.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-rrclab/run-3-query-asmk-retrieval/mast3r_inliers/query_100_inliers.pkl
# >> Loading a list of 2 images
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-1-wheelchair-mapping/rgb/2568.png with resolution 1280x720 --> 512x288
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-3-wheelchair-query/rgb/105.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-rrclab/run-3-query-asmk-retrieval/mast3r_inliers/query_105_inliers.pkl
# >> Loading a list of 2 images
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-1-wheelchair-mapping/rgb/2546.png with resolution 1280x720 --> 512x288
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-3-wheelchair-query/rgb/110.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-rrclab/run-3-query-asmk-retrieval/mast3r_inliers/query_110_inliers.pkl
# >> Loading a list of 2 images
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-1-wheelchair-mapping/rgb/2567.png with resolution 1280x720 --> 512x288
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-3-wheelchair-query/rgb/115.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-rrclab/run-3-query-asmk-retrieval/mast3r_inliers/query_115_inliers.pkl
# >> Loading a list of 2 images
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-1-wheelchair-mapping/rgb/2526.png with resolution 1280x720 --> 512x288
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-3-wheelchair-query/rgb/120.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-rrclab/run-3-query-asmk-retrieval/mast3r_inliers/query_120_inliers.pkl
# >> Loading a list of 2 images
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-1-wheelchair-mapping/rgb/2560.png with resolution 1280x720 --> 512x288
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-3-wheelchair-query/rgb/125.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-rrclab/run-3-query-asmk-retrieval/mast3r_inliers/query_125_inliers.pkl
# >> Loading a list of 2 images
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-1-wheelchair-mapping/rgb/2534.png with resolution 1280x720 --> 512x288
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-3-wheelchair-query/rgb/130.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-rrclab/run-3-query-asmk-retrieval/mast3r_inliers/query_130_inliers.pkl
# >> Loading a list of 2 images
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-1-wheelchair-mapping/rgb/2566.png with resolution 1280x720 --> 512x288
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-3-wheelchair-query/rgb/135.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-rrclab/run-3-query-asmk-retrieval/mast3r_inliers/query_135_inliers.pkl
# >> Loading a list of 2 images
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-1-wheelchair-mapping/rgb/2529.png with resolution 1280x720 --> 512x288
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-3-wheelchair-query/rgb/140.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-rrclab/run-3-query-asmk-retrieval/mast3r_inliers/query_140_inliers.pkl
# >> Loading a list of 2 images
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-1-wheelchair-mapping/rgb/2531.png with resolution 1280x720 --> 512x288
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-3-wheelchair-query/rgb/145.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-rrclab/run-3-query-asmk-retrieval/mast3r_inliers/query_145_inliers.pkl
# >> Loading a list of 2 images
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-1-wheelchair-mapping/rgb/2560.png with resolution 1280x720 --> 512x288
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-3-wheelchair-query/rgb/150.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-rrclab/run-3-query-asmk-retrieval/mast3r_inliers/query_150_inliers.pkl
# >> Loading a list of 2 images
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-1-wheelchair-mapping/rgb/2569.png with resolution 1280x720 --> 512x288
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-3-wheelchair-query/rgb/155.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-rrclab/run-3-query-asmk-retrieval/mast3r_inliers/query_155_inliers.pkl
# >> Loading a list of 2 images
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-1-wheelchair-mapping/rgb/2576.png with resolution 1280x720 --> 512x288
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-3-wheelchair-query/rgb/160.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-rrclab/run-3-query-asmk-retrieval/mast3r_inliers/query_160_inliers.pkl
# >> Loading a list of 2 images
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-1-wheelchair-mapping/rgb/2560.png with resolution 1280x720 --> 512x288
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-3-wheelchair-query/rgb/165.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-rrclab/run-3-query-asmk-retrieval/mast3r_inliers/query_165_inliers.pkl
# >> Loading a list of 2 images
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-1-wheelchair-mapping/rgb/2576.png with resolution 1280x720 --> 512x288
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-3-wheelchair-query/rgb/170.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-rrclab/run-3-query-asmk-retrieval/mast3r_inliers/query_170_inliers.pkl
# >> Loading a list of 2 images
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-1-wheelchair-mapping/rgb/2560.png with resolution 1280x720 --> 512x288
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-3-wheelchair-query/rgb/175.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-rrclab/run-3-query-asmk-retrieval/mast3r_inliers/query_175_inliers.pkl
# >> Loading a list of 2 images
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-1-wheelchair-mapping/rgb/2566.png with resolution 1280x720 --> 512x288
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-3-wheelchair-query/rgb/180.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-rrclab/run-3-query-asmk-retrieval/mast3r_inliers/query_180_inliers.pkl
# >> Loading a list of 2 images
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-1-wheelchair-mapping/rgb/2566.png with resolution 1280x720 --> 512x288
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-3-wheelchair-query/rgb/185.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-rrclab/run-3-query-asmk-retrieval/mast3r_inliers/query_185_inliers.pkl
# >> Loading a list of 2 images
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-1-wheelchair-mapping/rgb/2564.png with resolution 1280x720 --> 512x288
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-3-wheelchair-query/rgb/190.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-rrclab/run-3-query-asmk-retrieval/mast3r_inliers/query_190_inliers.pkl
# >> Loading a list of 2 images
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-1-wheelchair-mapping/rgb/2576.png with resolution 1280x720 --> 512x288
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-3-wheelchair-query/rgb/195.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-rrclab/run-3-query-asmk-retrieval/mast3r_inliers/query_195_inliers.pkl
# >> Loading a list of 2 images
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-1-wheelchair-mapping/rgb/2576.png with resolution 1280x720 --> 512x288
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-3-wheelchair-query/rgb/200.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-rrclab/run-3-query-asmk-retrieval/mast3r_inliers/query_200_inliers.pkl
# >> Loading a list of 2 images
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-1-wheelchair-mapping/rgb/2574.png with resolution 1280x720 --> 512x288
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-3-wheelchair-query/rgb/205.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-rrclab/run-3-query-asmk-retrieval/mast3r_inliers/query_205_inliers.pkl
# >> Loading a list of 2 images
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-1-wheelchair-mapping/rgb/2579.png with resolution 1280x720 --> 512x288
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-3-wheelchair-query/rgb/210.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-rrclab/run-3-query-asmk-retrieval/mast3r_inliers/query_210_inliers.pkl
# >> Loading a list of 2 images
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-1-wheelchair-mapping/rgb/2579.png with resolution 1280x720 --> 512x288
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-3-wheelchair-query/rgb/215.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-rrclab/run-3-query-asmk-retrieval/mast3r_inliers/query_215_inliers.pkl
# >> Loading a list of 2 images
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-1-wheelchair-mapping/rgb/2589.png with resolution 1280x720 --> 512x288
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-3-wheelchair-query/rgb/220.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-rrclab/run-3-query-asmk-retrieval/mast3r_inliers/query_220_inliers.pkl
# >> Loading a list of 2 images
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-1-wheelchair-mapping/rgb/2605.png with resolution 1280x720 --> 512x288
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-3-wheelchair-query/rgb/225.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-rrclab/run-3-query-asmk-retrieval/mast3r_inliers/query_225_inliers.pkl
# >> Loading a list of 2 images
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-1-wheelchair-mapping/rgb/2605.png with resolution 1280x720 --> 512x288
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-3-wheelchair-query/rgb/230.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-rrclab/run-3-query-asmk-retrieval/mast3r_inliers/query_230_inliers.pkl
# >> Loading a list of 2 images
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-1-wheelchair-mapping/rgb/2605.png with resolution 1280x720 --> 512x288
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-3-wheelchair-query/rgb/235.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-rrclab/run-3-query-asmk-retrieval/mast3r_inliers/query_235_inliers.pkl
# >> Loading a list of 2 images
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-1-wheelchair-mapping/rgb/2605.png with resolution 1280x720 --> 512x288
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-3-wheelchair-query/rgb/240.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-rrclab/run-3-query-asmk-retrieval/mast3r_inliers/query_240_inliers.pkl
# >> Loading a list of 2 images
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-1-wheelchair-mapping/rgb/2624.png with resolution 1280x720 --> 512x288
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-3-wheelchair-query/rgb/245.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-rrclab/run-3-query-asmk-retrieval/mast3r_inliers/query_245_inliers.pkl
# >> Loading a list of 2 images
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-1-wheelchair-mapping/rgb/2624.png with resolution 1280x720 --> 512x288
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-3-wheelchair-query/rgb/250.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-rrclab/run-3-query-asmk-retrieval/mast3r_inliers/query_250_inliers.pkl
# >> Loading a list of 2 images
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-1-wheelchair-mapping/rgb/2624.png with resolution 1280x720 --> 512x288
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-3-wheelchair-query/rgb/255.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-rrclab/run-3-query-asmk-retrieval/mast3r_inliers/query_255_inliers.pkl
# >> Loading a list of 2 images
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-1-wheelchair-mapping/rgb/2636.png with resolution 1280x720 --> 512x288
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-3-wheelchair-query/rgb/260.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-rrclab/run-3-query-asmk-retrieval/mast3r_inliers/query_260_inliers.pkl
# >> Loading a list of 2 images
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-1-wheelchair-mapping/rgb/2636.png with resolution 1280x720 --> 512x288
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-3-wheelchair-query/rgb/265.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-rrclab/run-3-query-asmk-retrieval/mast3r_inliers/query_265_inliers.pkl
# >> Loading a list of 2 images
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-1-wheelchair-mapping/rgb/2644.png with resolution 1280x720 --> 512x288
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-3-wheelchair-query/rgb/270.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-rrclab/run-3-query-asmk-retrieval/mast3r_inliers/query_270_inliers.pkl
# >> Loading a list of 2 images
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-1-wheelchair-mapping/rgb/2644.png with resolution 1280x720 --> 512x288
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-3-wheelchair-query/rgb/275.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-rrclab/run-3-query-asmk-retrieval/mast3r_inliers/query_275_inliers.pkl
# >> Loading a list of 2 images
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-1-wheelchair-mapping/rgb/2647.png with resolution 1280x720 --> 512x288
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-3-wheelchair-query/rgb/280.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-rrclab/run-3-query-asmk-retrieval/mast3r_inliers/query_280_inliers.pkl
# >> Loading a list of 2 images
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-1-wheelchair-mapping/rgb/2647.png with resolution 1280x720 --> 512x288
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-3-wheelchair-query/rgb/285.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-rrclab/run-3-query-asmk-retrieval/mast3r_inliers/query_285_inliers.pkl
# >> Loading a list of 2 images
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-1-wheelchair-mapping/rgb/2648.png with resolution 1280x720 --> 512x288
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-3-wheelchair-query/rgb/290.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-rrclab/run-3-query-asmk-retrieval/mast3r_inliers/query_290_inliers.pkl
# >> Loading a list of 2 images
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-1-wheelchair-mapping/rgb/2652.png with resolution 1280x720 --> 512x288
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-3-wheelchair-query/rgb/295.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-rrclab/run-3-query-asmk-retrieval/mast3r_inliers/query_295_inliers.pkl
# >> Loading a list of 2 images
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-1-wheelchair-mapping/rgb/2659.png with resolution 1280x720 --> 512x288
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-3-wheelchair-query/rgb/300.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-rrclab/run-3-query-asmk-retrieval/mast3r_inliers/query_300_inliers.pkl
# >> Loading a list of 2 images
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-1-wheelchair-mapping/rgb/2663.png with resolution 1280x720 --> 512x288
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-3-wheelchair-query/rgb/305.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-rrclab/run-3-query-asmk-retrieval/mast3r_inliers/query_305_inliers.pkl
# >> Loading a list of 2 images
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-1-wheelchair-mapping/rgb/2665.png with resolution 1280x720 --> 512x288
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-3-wheelchair-query/rgb/310.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-rrclab/run-3-query-asmk-retrieval/mast3r_inliers/query_310_inliers.pkl
# >> Loading a list of 2 images
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-1-wheelchair-mapping/rgb/2686.png with resolution 1280x720 --> 512x288
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-3-wheelchair-query/rgb/315.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-rrclab/run-3-query-asmk-retrieval/mast3r_inliers/query_315_inliers.pkl
# >> Loading a list of 2 images
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-1-wheelchair-mapping/rgb/2686.png with resolution 1280x720 --> 512x288
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-3-wheelchair-query/rgb/320.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-rrclab/run-3-query-asmk-retrieval/mast3r_inliers/query_320_inliers.pkl
# >> Loading a list of 2 images
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-1-wheelchair-mapping/rgb/2694.png with resolution 1280x720 --> 512x288
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-3-wheelchair-query/rgb/325.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-rrclab/run-3-query-asmk-retrieval/mast3r_inliers/query_325_inliers.pkl
# >> Loading a list of 2 images
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-1-wheelchair-mapping/rgb/2694.png with resolution 1280x720 --> 512x288
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-3-wheelchair-query/rgb/330.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-rrclab/run-3-query-asmk-retrieval/mast3r_inliers/query_330_inliers.pkl
# >> Loading a list of 2 images
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-1-wheelchair-mapping/rgb/2701.png with resolution 1280x720 --> 512x288
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-3-wheelchair-query/rgb/335.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-rrclab/run-3-query-asmk-retrieval/mast3r_inliers/query_335_inliers.pkl
# >> Loading a list of 2 images
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-1-wheelchair-mapping/rgb/2701.png with resolution 1280x720 --> 512x288
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-3-wheelchair-query/rgb/340.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-rrclab/run-3-query-asmk-retrieval/mast3r_inliers/query_340_inliers.pkl
# >> Loading a list of 2 images
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-1-wheelchair-mapping/rgb/2704.png with resolution 1280x720 --> 512x288
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-3-wheelchair-query/rgb/345.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-rrclab/run-3-query-asmk-retrieval/mast3r_inliers/query_345_inliers.pkl
# >> Loading a list of 2 images
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-1-wheelchair-mapping/rgb/2705.png with resolution 1280x720 --> 512x288
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-3-wheelchair-query/rgb/350.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-rrclab/run-3-query-asmk-retrieval/mast3r_inliers/query_350_inliers.pkl
# >> Loading a list of 2 images
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-1-wheelchair-mapping/rgb/2706.png with resolution 1280x720 --> 512x288
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-3-wheelchair-query/rgb/355.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-rrclab/run-3-query-asmk-retrieval/mast3r_inliers/query_355_inliers.pkl
# >> Loading a list of 2 images
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-1-wheelchair-mapping/rgb/2707.png with resolution 1280x720 --> 512x288
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-3-wheelchair-query/rgb/360.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-rrclab/run-3-query-asmk-retrieval/mast3r_inliers/query_360_inliers.pkl
# >> Loading a list of 2 images
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-1-wheelchair-mapping/rgb/2707.png with resolution 1280x720 --> 512x288
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-3-wheelchair-query/rgb/365.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-rrclab/run-3-query-asmk-retrieval/mast3r_inliers/query_365_inliers.pkl
# >> Loading a list of 2 images
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-1-wheelchair-mapping/rgb/2709.png with resolution 1280x720 --> 512x288
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-3-wheelchair-query/rgb/370.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-rrclab/run-3-query-asmk-retrieval/mast3r_inliers/query_370_inliers.pkl
# >> Loading a list of 2 images
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-1-wheelchair-mapping/rgb/2723.png with resolution 1280x720 --> 512x288
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-3-wheelchair-query/rgb/375.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-rrclab/run-3-query-asmk-retrieval/mast3r_inliers/query_375_inliers.pkl
# >> Loading a list of 2 images
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-1-wheelchair-mapping/rgb/2728.png with resolution 1280x720 --> 512x288
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-3-wheelchair-query/rgb/380.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-rrclab/run-3-query-asmk-retrieval/mast3r_inliers/query_380_inliers.pkl
# >> Loading a list of 2 images
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-1-wheelchair-mapping/rgb/2727.png with resolution 1280x720 --> 512x288
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-3-wheelchair-query/rgb/385.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-rrclab/run-3-query-asmk-retrieval/mast3r_inliers/query_385_inliers.pkl
# >> Loading a list of 2 images
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-1-wheelchair-mapping/rgb/2732.png with resolution 1280x720 --> 512x288
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-3-wheelchair-query/rgb/390.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-rrclab/run-3-query-asmk-retrieval/mast3r_inliers/query_390_inliers.pkl
# >> Loading a list of 2 images
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-1-wheelchair-mapping/rgb/2735.png with resolution 1280x720 --> 512x288
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-3-wheelchair-query/rgb/395.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-rrclab/run-3-query-asmk-retrieval/mast3r_inliers/query_395_inliers.pkl
# >> Loading a list of 2 images
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-1-wheelchair-mapping/rgb/2735.png with resolution 1280x720 --> 512x288
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-3-wheelchair-query/rgb/400.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-rrclab/run-3-query-asmk-retrieval/mast3r_inliers/query_400_inliers.pkl
# >> Loading a list of 2 images
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-1-wheelchair-mapping/rgb/2740.png with resolution 1280x720 --> 512x288
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-3-wheelchair-query/rgb/405.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-rrclab/run-3-query-asmk-retrieval/mast3r_inliers/query_405_inliers.pkl
# >> Loading a list of 2 images
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-1-wheelchair-mapping/rgb/2742.png with resolution 1280x720 --> 512x288
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-3-wheelchair-query/rgb/410.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-rrclab/run-3-query-asmk-retrieval/mast3r_inliers/query_410_inliers.pkl
# >> Loading a list of 2 images
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-1-wheelchair-mapping/rgb/2745.png with resolution 1280x720 --> 512x288
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-3-wheelchair-query/rgb/415.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-rrclab/run-3-query-asmk-retrieval/mast3r_inliers/query_415_inliers.pkl
# >> Loading a list of 2 images
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-1-wheelchair-mapping/rgb/2753.png with resolution 1280x720 --> 512x288
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-3-wheelchair-query/rgb/420.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-rrclab/run-3-query-asmk-retrieval/mast3r_inliers/query_420_inliers.pkl
# >> Loading a list of 2 images
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-1-wheelchair-mapping/rgb/2755.png with resolution 1280x720 --> 512x288
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-3-wheelchair-query/rgb/425.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-rrclab/run-3-query-asmk-retrieval/mast3r_inliers/query_425_inliers.pkl
# >> Loading a list of 2 images
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-1-wheelchair-mapping/rgb/2757.png with resolution 1280x720 --> 512x288
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-3-wheelchair-query/rgb/430.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-rrclab/run-3-query-asmk-retrieval/mast3r_inliers/query_430_inliers.pkl
# >> Loading a list of 2 images
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-1-wheelchair-mapping/rgb/2764.png with resolution 1280x720 --> 512x288
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-3-wheelchair-query/rgb/435.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-rrclab/run-3-query-asmk-retrieval/mast3r_inliers/query_435_inliers.pkl
# >> Loading a list of 2 images
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-1-wheelchair-mapping/rgb/2763.png with resolution 1280x720 --> 512x288
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-3-wheelchair-query/rgb/440.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-rrclab/run-3-query-asmk-retrieval/mast3r_inliers/query_440_inliers.pkl
# >> Loading a list of 2 images
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-1-wheelchair-mapping/rgb/2764.png with resolution 1280x720 --> 512x288
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-3-wheelchair-query/rgb/445.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-rrclab/run-3-query-asmk-retrieval/mast3r_inliers/query_445_inliers.pkl
# >> Loading a list of 2 images
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-1-wheelchair-mapping/rgb/2766.png with resolution 1280x720 --> 512x288
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-3-wheelchair-query/rgb/450.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-rrclab/run-3-query-asmk-retrieval/mast3r_inliers/query_450_inliers.pkl
# >> Loading a list of 2 images
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-1-wheelchair-mapping/rgb/2767.png with resolution 1280x720 --> 512x288
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-3-wheelchair-query/rgb/455.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-rrclab/run-3-query-asmk-retrieval/mast3r_inliers/query_455_inliers.pkl
# >> Loading a list of 2 images
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-1-wheelchair-mapping/rgb/2774.png with resolution 1280x720 --> 512x288
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-3-wheelchair-query/rgb/460.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-rrclab/run-3-query-asmk-retrieval/mast3r_inliers/query_460_inliers.pkl
# >> Loading a list of 2 images
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-1-wheelchair-mapping/rgb/2779.png with resolution 1280x720 --> 512x288
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-3-wheelchair-query/rgb/465.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-rrclab/run-3-query-asmk-retrieval/mast3r_inliers/query_465_inliers.pkl
# >> Loading a list of 2 images
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-1-wheelchair-mapping/rgb/2775.png with resolution 1280x720 --> 512x288
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-3-wheelchair-query/rgb/470.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-rrclab/run-3-query-asmk-retrieval/mast3r_inliers/query_470_inliers.pkl
# >> Loading a list of 2 images
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-1-wheelchair-mapping/rgb/2776.png with resolution 1280x720 --> 512x288
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-3-wheelchair-query/rgb/475.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-rrclab/run-3-query-asmk-retrieval/mast3r_inliers/query_475_inliers.pkl
# >> Loading a list of 2 images
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-1-wheelchair-mapping/rgb/2782.png with resolution 1280x720 --> 512x288
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-3-wheelchair-query/rgb/480.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-rrclab/run-3-query-asmk-retrieval/mast3r_inliers/query_480_inliers.pkl
# >> Loading a list of 2 images
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-1-wheelchair-mapping/rgb/2775.png with resolution 1280x720 --> 512x288
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-3-wheelchair-query/rgb/485.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-rrclab/run-3-query-asmk-retrieval/mast3r_inliers/query_485_inliers.pkl
# >> Loading a list of 2 images
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-1-wheelchair-mapping/rgb/2742.png with resolution 1280x720 --> 512x288
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-3-wheelchair-query/rgb/490.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-rrclab/run-3-query-asmk-retrieval/mast3r_inliers/query_490_inliers.pkl
# >> Loading a list of 2 images
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-1-wheelchair-mapping/rgb/2753.png with resolution 1280x720 --> 512x288
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-3-wheelchair-query/rgb/495.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-rrclab/run-3-query-asmk-retrieval/mast3r_inliers/query_495_inliers.pkl
# >> Loading a list of 2 images
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-1-wheelchair-mapping/rgb/2746.png with resolution 1280x720 --> 512x288
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-3-wheelchair-query/rgb/500.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-rrclab/run-3-query-asmk-retrieval/mast3r_inliers/query_500_inliers.pkl
# >> Loading a list of 2 images
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-1-wheelchair-mapping/rgb/2750.png with resolution 1280x720 --> 512x288
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-3-wheelchair-query/rgb/505.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-rrclab/run-3-query-asmk-retrieval/mast3r_inliers/query_505_inliers.pkl
# >> Loading a list of 2 images
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-1-wheelchair-mapping/rgb/2746.png with resolution 1280x720 --> 512x288
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-3-wheelchair-query/rgb/510.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-rrclab/run-3-query-asmk-retrieval/mast3r_inliers/query_510_inliers.pkl
# >> Loading a list of 2 images
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-1-wheelchair-mapping/rgb/2765.png with resolution 1280x720 --> 512x288
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-3-wheelchair-query/rgb/515.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-rrclab/run-3-query-asmk-retrieval/mast3r_inliers/query_515_inliers.pkl
# >> Loading a list of 2 images
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-1-wheelchair-mapping/rgb/2746.png with resolution 1280x720 --> 512x288
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-3-wheelchair-query/rgb/520.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-rrclab/run-3-query-asmk-retrieval/mast3r_inliers/query_520_inliers.pkl
# >> Loading a list of 2 images
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-1-wheelchair-mapping/rgb/2765.png with resolution 1280x720 --> 512x288
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-3-wheelchair-query/rgb/525.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-rrclab/run-3-query-asmk-retrieval/mast3r_inliers/query_525_inliers.pkl
# >> Loading a list of 2 images
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-1-wheelchair-mapping/rgb/2765.png with resolution 1280x720 --> 512x288
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-3-wheelchair-query/rgb/530.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-rrclab/run-3-query-asmk-retrieval/mast3r_inliers/query_530_inliers.pkl
# >> Loading a list of 2 images
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-1-wheelchair-mapping/rgb/2775.png with resolution 1280x720 --> 512x288
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-3-wheelchair-query/rgb/535.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-rrclab/run-3-query-asmk-retrieval/mast3r_inliers/query_535_inliers.pkl
# >> Loading a list of 2 images
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-1-wheelchair-mapping/rgb/2775.png with resolution 1280x720 --> 512x288
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-3-wheelchair-query/rgb/540.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-rrclab/run-3-query-asmk-retrieval/mast3r_inliers/query_540_inliers.pkl
# >> Loading a list of 2 images
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-1-wheelchair-mapping/rgb/2775.png with resolution 1280x720 --> 512x288
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-3-wheelchair-query/rgb/545.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-rrclab/run-3-query-asmk-retrieval/mast3r_inliers/query_545_inliers.pkl
# >> Loading a list of 2 images
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-1-wheelchair-mapping/rgb/2775.png with resolution 1280x720 --> 512x288
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-3-wheelchair-query/rgb/550.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-rrclab/run-3-query-asmk-retrieval/mast3r_inliers/query_550_inliers.pkl
# >> Loading a list of 2 images
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-1-wheelchair-mapping/rgb/2775.png with resolution 1280x720 --> 512x288
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-3-wheelchair-query/rgb/555.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-rrclab/run-3-query-asmk-retrieval/mast3r_inliers/query_555_inliers.pkl
# >> Loading a list of 2 images
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-1-wheelchair-mapping/rgb/2764.png with resolution 1280x720 --> 512x288
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-3-wheelchair-query/rgb/560.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-rrclab/run-3-query-asmk-retrieval/mast3r_inliers/query_560_inliers.pkl
# >> Loading a list of 2 images
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-1-wheelchair-mapping/rgb/2750.png with resolution 1280x720 --> 512x288
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-3-wheelchair-query/rgb/565.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-rrclab/run-3-query-asmk-retrieval/mast3r_inliers/query_565_inliers.pkl
# >> Loading a list of 2 images
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-1-wheelchair-mapping/rgb/2767.png with resolution 1280x720 --> 512x288
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-3-wheelchair-query/rgb/570.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-rrclab/run-3-query-asmk-retrieval/mast3r_inliers/query_570_inliers.pkl
# >> Loading a list of 2 images
# ...
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-rrclab/run-3-query-asmk-retrieval/mast3r_inliers/query_1590_inliers.pkl
# >> Loading a list of 2 images
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-1-wheelchair-mapping/rgb/1463.png with resolution 1280x720 --> 512x288
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-3-wheelchair-query/rgb/1595.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-rrclab/run-3-query-asmk-retrieval/mast3r_inliers/query_1595_inliers.pkl
# >> Loading a list of 2 images
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-1-wheelchair-mapping/rgb/1471.png with resolution 1280x720 --> 512x288
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-3-wheelchair-query/rgb/1600.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-rrclab/run-3-query-asmk-retrieval/mast3r_inliers/query_1600_inliers.pkl
# >> Loading a list of 2 images
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-1-wheelchair-mapping/rgb/1471.png with resolution 1280x720 --> 512x288
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-3-wheelchair-query/rgb/1605.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-rrclab/run-3-query-asmk-retrieval/mast3r_inliers/query_1605_inliers.pkl
# >> Loading a list of 2 images
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-1-wheelchair-mapping/rgb/1484.png with resolution 1280x720 --> 512x288
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-3-wheelchair-query/rgb/1610.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-rrclab/run-3-query-asmk-retrieval/mast3r_inliers/query_1610_inliers.pkl
# >> Loading a list of 2 images
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-1-wheelchair-mapping/rgb/1492.png with resolution 1280x720 --> 512x288
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-3-wheelchair-query/rgb/1615.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-rrclab/run-3-query-asmk-retrieval/mast3r_inliers/query_1615_inliers.pkl
# >> Loading a list of 2 images
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-1-wheelchair-mapping/rgb/1497.png with resolution 1280x720 --> 512x288
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-3-wheelchair-query/rgb/1620.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-rrclab/run-3-query-asmk-retrieval/mast3r_inliers/query_1620_inliers.pkl
# >> Loading a list of 2 images
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-1-wheelchair-mapping/rgb/1500.png with resolution 1280x720 --> 512x288
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-3-wheelchair-query/rgb/1625.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-rrclab/run-3-query-asmk-retrieval/mast3r_inliers/query_1625_inliers.pkl
# >> Loading a list of 2 images
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-1-wheelchair-mapping/rgb/1505.png with resolution 1280x720 --> 512x288
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-3-wheelchair-query/rgb/1630.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-rrclab/run-3-query-asmk-retrieval/mast3r_inliers/query_1630_inliers.pkl
# >> Loading a list of 2 images
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-1-wheelchair-mapping/rgb/1511.png with resolution 1280x720 --> 512x288
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-3-wheelchair-query/rgb/1635.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-rrclab/run-3-query-asmk-retrieval/mast3r_inliers/query_1635_inliers.pkl
# >> Loading a list of 2 images
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-1-wheelchair-mapping/rgb/1515.png with resolution 1280x720 --> 512x288
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-3-wheelchair-query/rgb/1640.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-rrclab/run-3-query-asmk-retrieval/mast3r_inliers/query_1640_inliers.pkl
# >> Loading a list of 2 images
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-1-wheelchair-mapping/rgb/1518.png with resolution 1280x720 --> 512x288
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-3-wheelchair-query/rgb/1645.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-rrclab/run-3-query-asmk-retrieval/mast3r_inliers/query_1645_inliers.pkl
# >> Loading a list of 2 images
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-1-wheelchair-mapping/rgb/1523.png with resolution 1280x720 --> 512x288
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-3-wheelchair-query/rgb/1650.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-rrclab/run-3-query-asmk-retrieval/mast3r_inliers/query_1650_inliers.pkl
# >> Loading a list of 2 images
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-1-wheelchair-mapping/rgb/1531.png with resolution 1280x720 --> 512x288
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-3-wheelchair-query/rgb/1655.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-rrclab/run-3-query-asmk-retrieval/mast3r_inliers/query_1655_inliers.pkl
# >> Loading a list of 2 images
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-1-wheelchair-mapping/rgb/1533.png with resolution 1280x720 --> 512x288
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-3-wheelchair-query/rgb/1660.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-rrclab/run-3-query-asmk-retrieval/mast3r_inliers/query_1660_inliers.pkl
# >> Loading a list of 2 images
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-1-wheelchair-mapping/rgb/1538.png with resolution 1280x720 --> 512x288
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-3-wheelchair-query/rgb/1665.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-rrclab/run-3-query-asmk-retrieval/mast3r_inliers/query_1665_inliers.pkl
# >> Loading a list of 2 images
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-1-wheelchair-mapping/rgb/1552.png with resolution 1280x720 --> 512x288
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-3-wheelchair-query/rgb/1670.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-rrclab/run-3-query-asmk-retrieval/mast3r_inliers/query_1670_inliers.pkl
# >> Loading a list of 2 images
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-1-wheelchair-mapping/rgb/1552.png with resolution 1280x720 --> 512x288
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-3-wheelchair-query/rgb/1675.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-rrclab/run-3-query-asmk-retrieval/mast3r_inliers/query_1675_inliers.pkl
# >> Loading a list of 2 images
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-1-wheelchair-mapping/rgb/1555.png with resolution 1280x720 --> 512x288
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-3-wheelchair-query/rgb/1680.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-rrclab/run-3-query-asmk-retrieval/mast3r_inliers/query_1680_inliers.pkl
# >> Loading a list of 2 images
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-1-wheelchair-mapping/rgb/1559.png with resolution 1280x720 --> 512x288
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-3-wheelchair-query/rgb/1685.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-rrclab/run-3-query-asmk-retrieval/mast3r_inliers/query_1685_inliers.pkl
# >> Loading a list of 2 images
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-1-wheelchair-mapping/rgb/1569.png with resolution 1280x720 --> 512x288
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-3-wheelchair-query/rgb/1690.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-rrclab/run-3-query-asmk-retrieval/mast3r_inliers/query_1690_inliers.pkl
# >> Loading a list of 2 images
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-1-wheelchair-mapping/rgb/1571.png with resolution 1280x720 --> 512x288
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-3-wheelchair-query/rgb/1695.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-rrclab/run-3-query-asmk-retrieval/mast3r_inliers/query_1695_inliers.pkl
# >> Loading a list of 2 images
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-1-wheelchair-mapping/rgb/1575.png with resolution 1280x720 --> 512x288
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-3-wheelchair-query/rgb/1700.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-rrclab/run-3-query-asmk-retrieval/mast3r_inliers/query_1700_inliers.pkl
# >> Loading a list of 2 images
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-1-wheelchair-mapping/rgb/1582.png with resolution 1280x720 --> 512x288
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-3-wheelchair-query/rgb/1705.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-rrclab/run-3-query-asmk-retrieval/mast3r_inliers/query_1705_inliers.pkl
# >> Loading a list of 2 images
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-1-wheelchair-mapping/rgb/1584.png with resolution 1280x720 --> 512x288
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-3-wheelchair-query/rgb/1710.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-rrclab/run-3-query-asmk-retrieval/mast3r_inliers/query_1710_inliers.pkl
# >> Loading a list of 2 images
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-1-wheelchair-mapping/rgb/1584.png with resolution 1280x720 --> 512x288
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-3-wheelchair-query/rgb/1715.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-rrclab/run-3-query-asmk-retrieval/mast3r_inliers/query_1715_inliers.pkl
# >> Loading a list of 2 images
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-1-wheelchair-mapping/rgb/1584.png with resolution 1280x720 --> 512x288
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-3-wheelchair-query/rgb/1720.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-rrclab/run-3-query-asmk-retrieval/mast3r_inliers/query_1720_inliers.pkl
# >> Loading a list of 2 images
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-1-wheelchair-mapping/rgb/1587.png with resolution 1280x720 --> 512x288
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-3-wheelchair-query/rgb/1725.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-rrclab/run-3-query-asmk-retrieval/mast3r_inliers/query_1725_inliers.pkl
# >> Loading a list of 2 images
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-1-wheelchair-mapping/rgb/1590.png with resolution 1280x720 --> 512x288
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-3-wheelchair-query/rgb/1730.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-rrclab/run-3-query-asmk-retrieval/mast3r_inliers/query_1730_inliers.pkl
# >> Loading a list of 2 images
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-1-wheelchair-mapping/rgb/1590.png with resolution 1280x720 --> 512x288
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-3-wheelchair-query/rgb/1735.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-rrclab/run-3-query-asmk-retrieval/mast3r_inliers/query_1735_inliers.pkl
# >> Loading a list of 2 images
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-1-wheelchair-mapping/rgb/1594.png with resolution 1280x720 --> 512x288
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-3-wheelchair-query/rgb/1740.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-rrclab/run-3-query-asmk-retrieval/mast3r_inliers/query_1740_inliers.pkl
# >> Loading a list of 2 images
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-1-wheelchair-mapping/rgb/1590.png with resolution 1280x720 --> 512x288
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-3-wheelchair-query/rgb/1745.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-rrclab/run-3-query-asmk-retrieval/mast3r_inliers/query_1745_inliers.pkl
# >> Loading a list of 2 images
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-1-wheelchair-mapping/rgb/1593.png with resolution 1280x720 --> 512x288
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-3-wheelchair-query/rgb/1750.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-rrclab/run-3-query-asmk-retrieval/mast3r_inliers/query_1750_inliers.pkl
# >> Loading a list of 2 images
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-1-wheelchair-mapping/rgb/1593.png with resolution 1280x720 --> 512x288
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-3-wheelchair-query/rgb/1755.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-rrclab/run-3-query-asmk-retrieval/mast3r_inliers/query_1755_inliers.pkl
# >> Loading a list of 2 images
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-1-wheelchair-mapping/rgb/1593.png with resolution 1280x720 --> 512x288
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-3-wheelchair-query/rgb/1760.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-rrclab/run-3-query-asmk-retrieval/mast3r_inliers/query_1760_inliers.pkl
# >> Loading a list of 2 images
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-1-wheelchair-mapping/rgb/1593.png with resolution 1280x720 --> 512x288
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-3-wheelchair-query/rgb/1765.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-rrclab/run-3-query-asmk-retrieval/mast3r_inliers/query_1765_inliers.pkl
# >> Loading a list of 2 images
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-1-wheelchair-mapping/rgb/1593.png with resolution 1280x720 --> 512x288
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-3-wheelchair-query/rgb/1770.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-rrclab/run-3-query-asmk-retrieval/mast3r_inliers/query_1770_inliers.pkl
# >> Loading a list of 2 images
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-1-wheelchair-mapping/rgb/1593.png with resolution 1280x720 --> 512x288
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-3-wheelchair-query/rgb/1775.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-rrclab/run-3-query-asmk-retrieval/mast3r_inliers/query_1775_inliers.pkl
# >> Loading a list of 2 images
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-1-wheelchair-mapping/rgb/1593.png with resolution 1280x720 --> 512x288
#  - adding data/rrc-lab-data/wheelchair-runs-20241220/run-3-wheelchair-query/rgb/1780.png with resolution 1280x720 --> 512x288
#  (Found 2 images)
# > Saved inliers to results/mast3rvloc-rrclab/run-3-query-asmk-retrieval/mast3r_inliers/query_1780_inliers.pkl
# > Saved GT camera poses to results/mast3rvloc-rrclab/run-3-query-asmk-retrieval/pred_poses_tum_query_down.txt

# %%
tum_mapping = file_interface.read_tum_trajectory_file(retrieved_ref_poses_file)
tum_query_gt = file_interface.read_tum_trajectory_file(filtered_query_poses_file)
tum_query_pred = file_interface.read_tum_trajectory_file(pred_poses_file_tum)

fig = plt.figure(figsize=(10, 20))
traj_by_label = {
    # "mapping_run": tum_mapping, 
    "query_run_gt": tum_query_gt,
    "query_run_pred": tum_query_pred,
}

plot.trajectories(fig, traj_by_label, plot.PlotMode.xy, plot_start_end_markers=True)
# plt.show()
plt.savefig(exp_folder / "trajectory_comparison.png")

# %%
import json
pose_relation = metrics.PoseRelation.translation_part
data = (tum_query_gt, tum_query_pred)

ape_metric = metrics.APE(pose_relation)
ape_metric.process_data(data)

ape_stats = ape_metric.get_all_statistics()
pprint.pprint(ape_stats)
# save ape stats as json
ape_stats_file = exp_folder / "ape_stats.json"
with open(ape_stats_file, 'w') as f:
    json.dump(ape_stats, f, indent=4)

fig = plt.figure()
plot.error_array(fig.gca(), ape_metric.error,
                statistics={s:v for s,v in ape_stats.items() if s != "sse"},
                name="APE", title="APE w.r.t. " + ape_metric.pose_relation.value, xlabel="$t$ (s)")
# plt.show()
plt.savefig(exp_folder / "trajectory_ape.png")
# Out:
# {'max': 4.500730536843633,
#  'mean': 0.5833737424039315,
#  'median': 0.19686215696914364,
#  'min': 0.0161783669378361,
#  'rmse': 0.9714412438356442,
#  'sse': 336.9002182103049,
#  'std': 0.7767709874207296}

# %%
plot_mode = plot.PlotMode.xy
fig = plt.figure(figsize=(15, 5))
ax = plot.prepare_axis(fig, plot_mode)
plot.traj(ax, plot_mode, tum_mapping, '--', "gray", "gt_query")
plot.traj_colormap(ax, tum_query_pred, ape_metric.error, plot_mode, min_map=ape_stats["min"], max_map=ape_stats["max"])
ax.legend()
# plt.show()
plt.savefig(exp_folder / "trajectory_ape_colormap.png")
